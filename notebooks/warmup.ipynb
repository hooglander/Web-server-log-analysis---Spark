// %% [markdown]
// # Warmup
//
// ## 1. Spark
// ### Basic RDD Operations
// The following steps demonstrate how to create an RDD from a file and apply transofrmations on it. Let's first creat an RDD, named `pagecounts`, from the input files located in `data/pagecounts`. The files entries will look something like this:
// ```
// 20090507-040000 zh favicon.ico 67 62955
// ```

// %%
val pagecounts = sc.textFile("data/pagecounts")
print(pagecounts)
// Out:
// data/pagecounts MapPartitionsRDD[1] at textFile at <console>:27
// pagecounts = data/pagecounts MapPartitionsRDD[1] at textFile at <console>:27
// data/pagecounts MapPartitionsRDD[1] at textFile at <console>:27
// (became,1)
// (battlements,1)
// (thick,3)
// (rat,3)
// (poisoner,2)
// (followd,1)
// (rites,2)
// (monument,1)
// (paradox,1)
// (full,11)
// (taste,1)
// (secure,2)
// (old,20)
// (feather,1)
// (roars,1)
// (bites,1)
// (tristful,1)
// (virtue,13)
// (bounds,1)
// (end,18)
// (norman,2)
// (brains,5)
// (wring,1)
// (nightly,1)
// (mourn,1)
// (whine,1)
// (looking,1)
// (labourd,1)
// (dard,1)
// (caviary,1)
// (less,8)
// (exchange,2)
// (falconers,1)
// (undertake,2)
// (compost,1)
// (reword,1)
// (aim,1)
// (book,4)
// (impress,1)
// (part,25)
// (shape,6)
// (different,1)
// (accident,3)
// (mother,39)
// (omen,1)
// (bears,2)
// (broach,1)
// (beseechd,1)
// (brings,1)
// (be,223)
// (incontinency,1)
// (bad,7)
// (eight,1)
// (punish,1)
// (backd,1)
// (valour,1)
// (grieves,1)
// (canon,1)
// (quake,1)
// (confines,1)
// (stops,2)
// (hyperions,1)
// (magic,1)
// (defective,1)
// (toward,6)
// (confesst,1)
// (strength,2)
// (garrisond,1)
// (metal,1)
// (but,274)
// (conceald,1)
// (pansies,1)
// (indifferently,1)
// (ten,4)
// (sconce,1)
// (guts,2)
// (returns,2)
// (arrow,1)
// (tyrannous,1)
// (occasion,4)
// (box,1)
// (small,1)
// (danish,6)
// (orisons,1)
// (vanishd,1)
// (sergeant,1)
// (doubtful,2)
// (touchd,1)
// (impatient,1)
// (phrase,10)
// (sepulchre,1)
// (extremity,2)
// (defect,2)
// (thrift,4)
// (gender,1)
// (sleepers,1)
// (credent,1)
// (mettle,1)
// (gallowsmaker,1)
// (divided,1)
// (busy,1)
// (bones,4)
// (skyish,1)
// (whither,1)
// (clutch,1)
// (majestical,2)
// (except,4)
// (invisible,1)
// (miching,1)
// (partial,1)
// (creep,1)
// (running,1)
// (fannd,1)
// (find,17)
// (challenger,1)
// (project,1)
// (steepd,1)
// (main,4)
// (coil,1)
// (green,2)
// (bouts,1)
// (deckd,1)
// (lions,1)
// (preaching,1)
// (ruld,3)
// (lies,6)
// (fixd,3)
// (loves,7)
// (awry,1)
// (liberal,2)
// (definement,1)
// (exceedingly,1)
// (months,4)
// (greeks,1)
// (invite,1)
// (dotes,1)
// (villanies,1)
// (write,1)
// (reverted,1)
// (cuckold,1)
// (provincial,1)
// (soaks,1)
// (tunes,2)
// (exercises,1)
// (trouble,2)
// (flies,1)
// (truth,6)
// (annual,1)
// (contracted,1)
// (fearsurprised,1)
// (husband,8)
// (knee,1)
// (aeneas,1)
// (offices,1)
// (pursy,1)
// (unripe,1)
// (reservd,1)
// (thence,4)
// (chronicles,1)
// (pate,4)
// (lug,1)
// (shot,6)
// (mewith,1)
// (theyll,1)
// (turneth,1)
// (afternoon,1)
// (eer,1)
// (dole,1)
// (apprehension,2)
// (order,3)
// (behind,9)
// (lenten,1)
// (convoy,1)
// (conjure,1)
// (rey,13)
// (sweart,1)
// (bout,1)
// (been,28)
// (rots,1)
// (reserve,1)
// (harlot,1)
// (jove,2)
// (persever,1)
// (breath,9)
// (hamlets,10)
// (jade,1)
// (compelld,1)
// (knows,4)
// (likeness,1)
// (secrecy,3)
// (jephthah,3)
// (tune,2)
// (are,132)
// (records,1)
// (smooth,2)
// (shut,1)
// (grant,1)
// (brief,5)
// (morn,3)
// (element,1)
// (poisond,3)
// (tush,2)
// (cart,1)
// (stern,1)
// (safely,2)
// (robin,1)
// (wager,6)
// (overhappy,1)
// (throne,2)
// (oerstep,1)
// (son,22)
// (dead,31)
// (midnight,1)
// (aptly,1)
// (thus,43)
// (ulcerous,1)
// (jointlabourer,1)
// (glares,1)
// (pursue,2)
// (them,74)
// (female,1)
// (cor,1)
// (nods,1)
// (compounded,1)
// (oerleavens,1)
// (bravery,1)
// (staid,1)
// (subscribd,1)
// (oerdoing,1)
// (third,3)
// (volley,1)
// (fools,2)
// (neck,3)
// (cried,3)
// (pace,2)
// (unholy,1)
// (decayer,1)
// (seeing,4)
// (gem,1)
// (dirt,2)
// (absolute,2)
// (observd,1)
// (east,1)
// (saying,1)
// (draws,3)
// (meeting,2)
// (strangely,2)
// (unfortified,1)
// (garbage,1)
// (sprung,1)
// (grandsire,1)
// (lines,3)
// (deject,1)
// (doublet,1)
// (twas,4)
// (sliver,1)
// (hit,6)
// (chapless,1)
// (closes,4)
// (emulate,1)
// (scannd,1)
// (mole,2)
// (hot,6)
// (things,12)
// (lord,225)
// (buys,1)
// (aslant,1)
// (stiffly,1)
// (cars,1)
// (quaintly,1)
// (apparel,1)
// (rub,2)
// (scald,1)
// (made,30)
// (cannoneer,1)
// (city,2)
// (hypocrite,1)
// (yawn,1)
// (sblood,2)
// (proportions,1)
// (wildly,2)
// (stomach,1)
// (buried,6)
// (quick,8)
// (mortal,5)
// (hymen,1)
// (audit,1)
// (fat,6)
// (habits,1)
// (blanks,1)
// (heads,2)
// (crants,1)
// (worlds,2)
// (fame,2)
// (moor,1)
// (strokes,1)
// (good,109)
// (devices,1)
// (blows,2)
// (wanton,3)
// (toys,1)
// (potently,1)
// (ubique,1)
// (stamp,2)
// (cockle,1)
// (bodiless,1)
// (unwilling,1)
// (judicious,1)
// (rags,1)
// (left,3)
// (admirable,1)
// (breaking,1)
// (forestalled,1)
// (nighted,1)
// (oerwhelm,1)
// (custom,9)
// (thyself,5)
// (creation,1)
// (affection,4)
// (forged,1)
// (ankle,1)
// (impasted,1)
// (perilous,1)
// (guilt,3)
// (request,1)
// (spirit,14)
// (dramatis,1)
// (sandal,1)
// (watchman,1)
// (effect,7)
// (paddling,1)
// (augury,1)
// (cyclops,1)
// (frame,4)
// (valentines,1)
// (freefooted,1)
// (fell,9)
// (age,9)
// (damon,1)
// (bawds,1)
// (frankly,2)
// (heavenkissing,1)
// (tonight,11)
// (perceive,1)
// (choose,5)
// (pregnant,2)
// (obstinate,1)
// (spendthrift,1)
// (contend,1)
// (doubts,1)
// (strucken,1)
// (owner,1)
// (pah,1)
// (witness,2)
// (stockings,1)
// (lights,4)
// (attended,1)
// (clay,3)
// (relish,2)
// (opposd,1)
// (delay,2)
// (judge,3)
// (amber,1)
// (steal,1)
// (brows,2)
// (servant,3)
// (returneth,1)
// (uncharge,1)
// (fingerd,1)
// (globe,1)
// (hallowd,1)
// (rashly,1)
// (treacherous,2)
// (wash,2)
// (seen,22)
// (pays,1)
// (promontory,1)
// (edge,3)
// (birth,4)
// (venomd,1)
// (encountred,1)
// (lives,4)
// (target,1)
// (pressure,1)
// (beast,6)
// (fit,12)
// (unprofitable,1)
// (brought,6)
// (easiness,2)
// (wisest,3)
// (desert,2)
// (fellowship,2)
// (if,114)
// (leaps,2)
// (leisure,4)
// (jowls,1)
// (windlasses,1)
// (secrets,1)
// (prayst,1)
// (knowt,1)
// (guard,4)
// (honourable,3)
// (prince,5)
// (regard,2)
// (gonzago,3)
// (grief,14)
// (lockd,2)
// (passages,1)
// (dislike,1)
// (dearly,2)
// (forget,4)
// (lists,1)
// (umbrage,1)
// (messenger,4)
// (swift,2)
// (lawless,2)
// (had,44)
// (let,96)
// (unhousled,1)
// (dream,6)
// (perfect,1)
// (across,1)
// (settled,1)
// (rage,3)
// (felicity,1)
// (captains,1)
// (semblable,1)
// (touching,3)
// (postscript,1)
// (aroused,1)
// (thart,1)
// (slight,1)
// (commencement,1)
// (hammers,1)
// (divine,1)
// (accepts,1)
// (antic,1)
// (ardour,1)
// (tatters,1)
// (tears,8)
// (sober,1)
// (damned,6)
// (gait,2)
// (rusty,1)
// (allegiance,1)
// (woot,5)
// (salvation,2)
// (deliverd,1)
// (swaggring,1)
// (behove,1)
// (circumstance,6)
// (la,1)
// (burn,2)
// (killed,1)
// (sting,2)
// (serve,2)
// (catch,2)
// (unnerved,1)
// (false,6)
// (artire,1)
// (seald,5)
// (ha,6)
// (say,54)
// (days,5)
// (perform,1)
// (reads,4)
// (womans,1)
// (scarce,2)
// (fret,1)
// (supposal,1)
// (divulging,1)
// (quoth,1)
// (fellow,10)
// (profane,1)
// (shipwright,2)
// (saw,12)
// (bend,3)
// (poem,1)
// (innovation,1)
// (swinish,1)
// (individable,1)
// (inward,3)
// (prologue,5)
// (millions,1)
// (seems,6)
// (performd,2)
// (seet,1)
// (leperous,1)
// (foils,6)
// (ratifiers,1)
// (esteemd,1)
// (water,6)
// (murdrous,1)
// (grosser,1)
// (nettles,1)
// (bloody,7)
// (confession,3)
// (mercury,1)
// (dalliance,1)
// (religious,1)
// (conversation,1)
// (confront,1)
// (unbracd,1)
// (incapable,1)
// (message,1)
// (sale,1)
// (northnorthwest,1)
// (cousin,4)
// (plentiful,1)
// (grey,1)
// (side,2)
// (whispers,1)
// (prayer,2)
// (adam,1)
// (amble,1)
// (touch,6)
// (jangled,1)
// (ground,9)
// (orderly,1)
// (pernicious,1)
// (seneca,1)
// (wing,1)
// (scant,1)
// (forgetting,1)
// (worthy,1)
// (snow,4)
// (stealing,1)
// (pall,1)
// (spring,3)
// (much,48)
// (also,1)
// (squeezing,1)
// (france,5)
// (compare,1)
// (treads,1)
// (altogether,1)
// (whore,1)
// (blastments,1)
// (knowest,1)
// (author,2)
// (hebona,1)
// (pleasure,4)
// (base,5)
// (entreat,3)
// (source,2)
// (majesties,2)
// (flights,1)
// (shards,1)
// (absent,1)
// (treachery,2)
// (strongest,1)
// (villain,11)
// (nutshell,1)
// (off,21)
// (simples,1)
// (horrors,1)
// (document,1)
// (shreds,1)
// (shes,2)
// (ply,1)
// (weed,1)
// (valancd,1)
// (shadows,2)
// (cabin,1)
// (justly,3)
// (sawt,1)
// (dreadful,3)
// (ache,1)
// (dews,1)
// (corner,1)
// (thunders,1)
// (coffin,1)
// (maid,6)
// (slain,6)
// (recorders,3)
// (denied,1)
// (rightly,1)
// (compact,1)
// (angel,4)
// (sensibly,1)
// (tables,2)
// (those,21)
// (theres,18)
// (priam,4)
// (stole,3)
// (neighbourd,1)
// (shipped,1)
// (easier,1)
// (manner,1)
// (mans,5)
// (attends,1)
// (greet,1)
// (repair,2)
// (course,5)
// (breach,1)
// (view,2)
// (within,23)
// (wife,8)
// (importing,3)
// (ago,1)
// (ready,4)
// (modesties,1)
// (lick,1)
// (wooes,1)
// (sickly,2)
// (thy,86)
// (weapons,1)
// (theatre,1)
// (sorry,4)
// (rawer,1)
// (match,1)
// (everything,2)
// (adders,1)
// (relievd,2)
// (to,742)
// (kettle,1)
// (westward,1)
// (core,1)
// (loggets,1)
// (debt,1)
// (wail,1)
// (sisters,1)
// (rack,1)
// (yea,4)
// (readshigh,1)
// (watch,15)
// (cheer,3)
// (honeying,1)
// (fairly,1)
// (sate,2)
// (acted,1)
// (denmarks,3)
// (thought,11)
// (corses,1)
// (tragicalhistorical,1)
// (safe,2)
// (wonder,3)
// (elsinore,23)
// (sensible,1)
// (solidity,1)
// (it,419)
// (twould,1)
// (buyer,1)
// (others,6)
// (shoot,1)
// (varnish,1)
// (embrace,2)
// (nothing,30)
// (content,3)
// (whoreson,2)
// (doors,3)
// (unlimited,1)
// (naked,2)
// (hideous,2)
// (spark,1)
// (sewing,1)
// (he,213)
// (harrow,1)
// (firmament,1)
// (bridebed,1)
// (extorted,1)
// (unimproved,1)
// (exact,1)
// (centre,1)
// (threaten,1)
// (sheen,1)
// (afoot,1)
// (task,1)
// (gambols,1)
// (villany,1)
// (double,6)
// (govern,1)
// (inclind,1)
// (southerly,1)
// (beaten,1)
// (england,20)
// (luxury,1)
// (homage,1)
// (beseech,7)
// (hard,5)
// (eaten,1)
// (carriages,5)
// (drowns,1)
// (affliction,3)
// (shaking,1)
// (music,8)
// (given,10)
// (determine,1)
// (cutpurse,1)
// (unshaken,1)
// (pith,3)
// (proceeded,1)
// (befitted,1)
// (coldly,2)
// (tame,3)
// (wary,2)
// (story,3)
// (ambassador,2)
// (sins,2)
// (ungord,1)
// (gentlemen,14)
// (angle,1)
// (toils,1)
// (hoodmanblind,1)
// (behaviour,2)
// (presentment,1)
// (vice,3)
// (arrest,1)
// (extinct,1)
// (stung,1)
// (mens,3)
// (wrong,6)
// (ant,2)
// (collateral,1)
// (monsters,1)
// (retirement,1)
// (periwigpated,1)
// (sorrows,1)
// (rot,1)
// (wonted,2)
// (beckons,3)
// (person,4)
// (mantle,1)
// (meant,4)
// (olympus,1)
// (pit,3)
// (liest,3)
// (groaning,1)
// (while,14)
// (churchyard,1)
// (witherd,1)
// (ths,1)
// (speed,4)
// (bold,3)
// (violence,4)
// (wisely,2)
// (purgation,1)
// (drinks,3)
// (hoops,1)
// (distress,1)
// (corruption,3)
// (children,3)
// (tot,8)
// (portraiture,1)
// (demand,2)
// (benefit,1)
// (obsequious,1)
// (poisoned,1)
// (may,71)
// (puzzles,1)
// (seat,2)
// (unschoold,1)
// (alarm,2)
// (command,10)
// (breeder,1)
// (columbines,1)
// (unfledgd,1)
// (sudden,5)
// (fardels,1)
// (swaddling,1)
// (or,115)
// (limed,1)
// (saint,3)
// (yorick,1)
// (thoughtsick,1)
// (spokes,2)
// (antique,2)
// (of,675)
// (transformation,1)
// (sanctuarize,1)
// (savoury,1)
// (barbers,1)
// (reach,1)
// (straw,2)
// (wrist,1)
// (actively,1)
// (beards,1)
// (functions,1)
// (impartment,1)
// (pagan,1)
// (therein,1)
// (lock,2)
// (working,2)
// (gilded,1)
// (reasons,2)
// (led,1)
// (pluck,3)
// (desk,1)
// (bawdy,1)
// (back,8)
// (negligence,1)
// (infants,1)
// (cuffs,1)
// (apparition,2)
// (native,4)
// (dot,9)
// (pox,1)
// (cups,1)
// (heathen,1)
// (greeting,1)
// (dreaded,1)
// (march,6)
// (argument,4)
// (each,11)
// (personae,1)
// (laugh,6)
// (approve,2)
// (chalice,1)
// (threats,1)
// (commend,4)
// (herb,1)
// (range,1)
// (refrain,1)
// (amiss,2)
// (unclefather,1)
// (remains,3)
// (doing,1)
// (outbreak,1)
// (tend,4)
// (didest,1)
// (necessaries,1)
// (indeed,31)
// (did,66)
// (upshot,1)
// (time,46)
// (vouchers,2)
// (unmask,1)
// (sweaty,1)
// (moan,1)
// (madness,22)
// (imitated,1)
// (abate,1)
// (coming,7)
// (incorrect,1)
// (diseases,1)
// (aught,10)
// (mute,1)
// (clout,1)
// (former,3)
// (inform,2)
// (weeping,1)
// (taints,1)
// (steel,3)
// (couplets,1)
// (no,142)
// (moult,1)
// (sexton,1)
// (rheum,1)
// (desires,4)
// (forgiveness,1)
// (noblest,1)
// (verity,1)
// (far,11)
// (slave,4)
// (disposition,5)
// (pulse,1)
// (hairs,1)
// (oph,58)
// (perhaps,5)
// (frailty,1)
// (jointress,1)
// (fort,6)
// (jaws,1)
// (prompted,1)
// (jester,1)
// (commingled,1)
// (potion,1)
// (creature,2)
// (nation,3)
// (trace,2)
// (quantity,4)
// (dowry,1)
// (grievd,1)
// (scripture,2)
// (stages,1)
// (bid,6)
// (profoundest,1)
// (dungeons,1)
// (whole,7)
// (spots,1)
// (grow,8)
// (sworn,2)
// (impetuous,1)
// (yonder,2)
// (truster,1)
// (videlicet,1)
// (soild,1)
// (satyr,1)
// (builds,2)
// (wearing,1)
// (winch,1)
// (blame,3)
// (solid,1)
// (wrote,2)
// (drugs,1)
// (storm,1)
// (silverd,1)
// (worst,1)
// (seal,3)
// (concluded,1)
// (purples,1)
// (clambring,1)
// (comedy,2)
// (fox,1)
// (matter,27)
// (groundas,1)
// (convert,2)
// (loudly,1)
// (dip,1)
// (believd,1)
// (that,389)
// (many,18)
// (customary,1)
// (speedier,1)
// (multitude,1)
// (choice,6)
// (strikes,1)
// (pickers,1)
// (stair,1)
// (twere,12)
// (sight,9)
// (crafty,1)
// (recognizances,1)
// (distilld,1)
// (canst,3)
// (houses,2)
// (west,1)
// (consonancy,1)
// (craven,1)
// (tragicalcomicalhistoricalpastoral,1)
// (wore,1)
// (patience,5)
// (direct,4)
// (vacancy,1)
// (striking,1)
// (wherefore,3)
// (purposd,2)
// (devotions,1)
// (downgyved,1)
// (outlives,1)
// (blazes,1)
// (falsehood,1)
// (allow,1)
// (bodes,1)
// (leave,28)
// (cruel,2)
// (mirror,2)
// (puppets,1)
// (gifts,5)
// (sharkd,1)
// (uncle,9)
// (loss,1)
// (common,7)
// (woodcock,1)
// (adown,2)
// (kettledrum,1)
// (force,3)
// (swounds,2)
// (violent,4)
// (along,3)
// (articles,1)
// (hap,1)
// (converse,1)
// (slaughter,1)
// (walk,9)
// (eyelids,1)
// (twenty,3)
// (doth,28)
// (spread,2)
// (needfull,1)
// (doomd,1)
// (awe,2)
// (wars,2)
// (either,6)
// (erring,1)
// (longer,6)
// (scatters,1)
// (charitable,2)
// (orchard,2)
// (unmixd,1)
// (earthly,1)
// (painted,2)
// (oerreaches,1)
// (claudio,1)
// (stowd,1)
// (honour,10)
// (necessity,1)
// (lend,4)
// (ducat,1)
// (laws,1)
// (sultry,2)
// (instrument,2)
// (happily,2)
// (napkin,1)
// (rights,2)
// (closely,1)
// (pours,2)
// (assay,3)
// (niobe,1)
// (move,6)
// (sentinelsfirst,1)
// (deliberate,1)
// (harshly,1)
// (chances,2)
// (itself,24)
// (lament,1)
// (winnowed,1)
// (siege,1)
// (complete,1)
// (combated,1)
// (slow,3)
// (supper,2)
// (apiece,1)
// (monarchs,1)
// (show,23)
// (pastime,2)
// (on,128)
// (gone,14)
// (posthaste,1)
// (concernings,1)
// (would,81)
// (untimely,1)
// (fates,2)
// (lungs,2)
// (crash,1)
// (treasure,4)
// (wipe,2)
// (stewd,1)
// (caps,1)
// (statutes,1)
// (authorities,1)
// (unweeded,1)
// (gave,8)
// (muddy,1)
// (crust,1)
// (1604,1)
// (year,5)
// (hobbyhorse,2)
// (tongues,3)
// (journeys,1)
// (ambitious,3)
// (unmastred,1)
// (prick,1)
// (prison,6)
// (crowflowers,1)
// (bent,3)
// (judgments,3)
// (epitaph,2)
// (cases,1)
// (oersized,1)
// (shine,1)
// (oaths,1)
// (fertile,1)
// (soon,1)
// (private,1)
// (indiscretion,1)
// (pickaxe,1)
// (hasten,1)
// (forward,3)
// (dipping,1)
// (gracious,6)
// (eternal,2)
// (frock,1)
// (conjures,1)
// (courtier,10)
// (hent,1)
// (kllld,1)
// (asking,2)
// (player,5)
// (scorn,1)
// (devisd,1)
// (points,2)
// (legs,1)
// (encounter,3)
// (yourselves,1)
// (wringing,1)
// (hems,1)
// (graces,2)
// (making,3)
// (repast,1)
// (branchesit,1)
// (grave,11)
// (eldest,1)
// (goosequills,1)
// (chide,1)
// (prickd,1)
// (fran,8)
// (provd,3)
// (hedge,1)
// (glean,1)
// (heres,8)
// (yaw,1)
// (hawk,1)
// (rise,2)
// (sheep,1)
// (avoid,3)
// (danger,5)
// (levied,1)
// (enters,1)
// (honest,11)
// (odd,2)
// (instance,1)
// (ill,62)
// (prepare,3)
// (glassy,1)
// (suffer,3)
// (smelt,1)
// (beautied,1)
// (competent,1)
// (carefully,1)
// (soul,34)
// (wards,1)
// (student,1)
// (hearer,1)
// (charm,1)
// (merry,2)
// (character,2)
// (sulphrous,1)
// (minister,1)
// (thumbs,1)
// (loving,3)
// (churches,1)
// (your,242)
// (humbly,5)
// (witching,1)
// (enterprise,2)
// (consummation,1)
// (burnt,1)
// (censure,4)
// (up,39)
// (scholars,2)
// (influence,1)
// (feels,1)
// (insinuation,1)
// (argues,1)
// (casual,1)
// (passion,11)
// (wear,4)
// (razd,1)
// (commendable,1)
// (awake,2)
// (gape,1)
// (outwards,1)
// (non,1)
// (fantastic,1)
// (rome,2)
// (suppress,2)
// (room,13)
// (then,65)
// (said,15)
// (fires,1)
// (philosophy,2)
// (bar,1)
// (anoint,1)
// (dild,1)
// (pronounce,1)
// (today,2)
// (appeard,3)
// (like,81)
// (extravagant,1)
// (bought,1)
// (stalk,1)
// (followers,1)
// (punishd,1)
// (recoveries,2)
// (wast,3)
// (repentance,1)
// (carnal,1)
// (lackd,1)
// (requite,2)
// (thanks,10)
// (operant,1)
// (garland,1)
// (foresaid,1)
// (violet,1)
// (song,1)
// (garden,2)
// (born,3)
// (jocund,1)
// (thin,2)
// (nill,1)
// (consider,2)
// (marching,1)
// (bugs,1)
// (oerbears,1)
// (rareness,1)
// (convenience,1)
// (carve,1)
// (loins,1)
// (growing,1)
// (hell,11)
// (theft,1)
// (ones,2)
// (breathe,3)
// (kibe,1)
// (endure,1)
// (lo,3)
// (funeral,5)
// (drabbing,1)
// (eclipse,1)
// (kindless,1)
// (wide,4)
// (occulted,1)
// (springes,1)
// (northerly,1)
// (amazd,1)
// (holding,1)
// (thereabout,1)
// (tween,1)
// (respeaking,1)
// (panders,1)
// (way,11)
// (buzz,2)
// (radiant,1)
// (deeds,1)
// (tenable,1)
// (daughters,1)
// (every,8)
// (nature,27)
// (mystery,1)
// (smiles,1)
// (sing,5)
// (throws,2)
// (moe,1)
// (declining,1)
// (smiling,3)
// (front,1)
// (crowing,1)
// (moiety,1)
// (state,15)
// (dies,7)
// (wits,5)
// (selfslaughter,1)
// (begun,4)
// (large,1)
// (hecates,1)
// (showing,1)
// (amen,1)
// (mournd,1)
// (dilated,1)
// (sirrah,1)
// (retrograde,1)
// (shuffled,1)
// (foreknowing,1)
// (power,8)
// (littlest,1)
// (dropping,1)
// (feast,3)
// (opposite,1)
// (and,964)
// (verse,1)
// (hill,3)
// (actor,3)
// (associates,1)
// (gallows,3)
// (burial,4)
// (observers,1)
// (reaches,1)
// (wretch,3)
// (invulnerable,1)
// (protest,1)
// (sirs,3)
// (revisits,1)
// (told,5)
// (promisecrammd,1)
// (youth,16)
// (vows,6)
// (evidence,1)
// (turf,1)
// (dirge,1)
// (encompassment,1)
// (pictures,1)
// (hasty,1)
// (place,9)
// (silence,5)
// (liberalconceited,1)
// (wag,2)
// (unbated,2)
// (palmy,1)
// (spite,1)
// (handsome,1)
// (makes,18)
// (womens,1)
// (cicatrice,1)
// (melodious,1)
// (mourning,1)
// (accurst,1)
// (diameter,1)
// (pulld,1)
// (deathbed,1)
// (taxd,1)
// (lawful,1)
// (vulgar,2)
// (fearful,1)
// (wealth,1)
// (godamercy,1)
// (strewd,1)
// (jot,2)
// (vienna,1)
// (heartache,1)
// (dishonour,2)
// (alone,10)
// (process,3)
// (remembred,1)
// (debatement,1)
// (most,82)
// (eleven,1)
// (easily,1)
// (illbreeding,1)
// (oersways,1)
// (bat,2)
// (home,6)
// (forest,1)
// (thrice,4)
// (certainty,1)
// (carry,3)
// (really,1)
// (acts,2)
// (pales,1)
// (revolution,1)
// (perchance,5)
// (combination,1)
// (mood,1)
// (constantly,1)
// (diggd,1)
// (baser,2)
// (pass,6)
// (larger,1)
// (commandment,4)
// (fears,2)
// (clothe,1)
// (license,1)
// (confess,5)
// (bell,2)
// (instructs,1)
// (frontier,1)
// (middle,2)
// (rebels,1)
// (tugging,1)
// (chapel,2)
// (compulsive,1)
// (brazd,1)
// (art,17)
// (skill,3)
// (hautboys,1)
// (dreamt,1)
// (exeunt,37)
// (nor,37)
// (impression,1)
// (visit,5)
// (seven,1)
// (proclaim,2)
// (necessary,2)
// (scopes,1)
// (steep,1)
// (praisd,2)
// (joys,2)
// (gentlewoman,1)
// (stands,4)
// (byandby,4)
// (masterly,1)
// (at,87)
// (fancy,3)
// (snatches,1)
// (object,1)
// (diseasd,1)
// (frowningly,1)
// (suchaones,1)
// (examples,1)
// (natural,5)
// (lightness,1)
// (confind,1)
// (calveskins,1)
// (tremble,2)
// (drains,1)
// (parley,1)
// (give,60)
// (bias,1)
// (inclining,1)
// (galled,1)
// (beck,1)
// (milk,1)
// (weakness,2)
// (church,2)
// (teach,4)
// (retain,1)
// (methought,4)
// (godlike,1)
// (modesty,4)
// (hall,4)
// (blister,1)
// (weal,1)
// (successive,1)
// (brook,2)
// (exception,1)
// (feelingly,1)
// (whats,11)
// (broken,1)
// (prettiness,1)
// (events,1)
// (lovd,5)
// (honourd,5)
// (sticks,1)
// (excitements,1)
// (election,3)
// (advancd,1)
// (gets,1)
// (reels,1)
// (exposing,1)
// (rose,4)
// (resemble,1)
// (inky,1)
// (buffets,1)
// (trumpet,5)
// (livd,1)
// (primal,1)
// (quiddits,1)
// (falln,3)
// (murther,14)
// (cozend,1)
// (amercy,1)
// (douts,1)
// (sole,1)
// (applaud,1)
// (relief,1)
// (detecting,1)
// (for,250)
// (immediate,2)
// (cause,17)
// (supply,1)
// (hor,109)
// (property,4)
// (mew,1)
// (gallant,1)
// (empty,1)
// (present,4)
// (anger,1)
// (delicate,2)
// (cool,1)
// (temple,1)
// (villanous,1)
// (begin,6)
// (cure,1)
// (humanity,1)
// (wishes,1)
// (people,1)
// (crafts,1)
// (seizd,1)
// (was,84)
// (goodman,1)
// (eye,15)
// (merit,2)
// (unkind,1)
// (do,151)
// (hearts,3)
// (carrying,2)
// (royal,3)
// (convocation,1)
// (letters,9)
// (richer,2)
// (preparation,1)
// (roman,2)
// (pat,1)
// (limbs,2)
// (valiant,2)
// (proclaimd,1)
// (count,3)
// (shoon,1)
// (temperd,1)
// (esill,1)
// (comrade,1)
// (machine,1)
// (wondrous,3)
// (pioner,1)
// (presence,3)
// (fought,1)
// (calumny,1)
// (twofold,1)
// (prosperously,1)
// (affair,4)
// (hurt,2)
// (behooves,1)
// (season,6)
// (fairy,1)
// (mere,3)
// (eterne,1)
// (couched,1)
// (whos,1)
// (bounty,1)
// (garments,1)
// (might,32)
// (higher,1)
// (spills,1)
// (commerce,1)
// (assurance,2)
// (wood,1)
// (in,434)
// (celebrated,1)
// (powerfully,1)
// (yield,2)
// (concernancy,1)
// (milch,1)
// (aimd,1)
// (indict,1)
// (comes,25)
// (sail,3)
// (grassgreen,1)
// (doom,1)
// (sleeping,4)
// (pitiful,1)
// (passes,1)
// (mote,1)
// (flame,2)
// (ulcer,1)
// (public,1)
// (skin,1)
// (apt,2)
// (faithful,3)
// (horrible,4)
// (keep,19)
// (easing,1)
// (dying,1)
// (fetters,1)
// (ordinant,1)
// (deceived,1)
// (abridgment,1)
// (composd,1)
// (hopes,1)
// (cannon,4)
// (damnation,1)
// (formal,1)
// (goblin,1)
// (slander,2)
// (succession,2)
// (posy,1)
// (enact,2)
// (hercules,3)
// (tax,1)
// (barbary,2)
// (traveller,1)
// (instant,4)
// (donnd,1)
// (iv,4)
// (newly,1)
// (poppd,1)
// (interpret,1)
// (resort,1)
// (slay,1)
// (noyance,1)
// (offends,1)
// (famous,1)
// (reverend,1)
// (hath,65)
// (changes,1)
// (rankly,1)
// (reformd,1)
// (praises,1)
// (needs,7)
// (rosencrantz,26)
// (halfpenny,1)
// (afeard,1)
// (battalions,1)
// (flagon,1)
// (disclosd,2)
// (likewise,1)
// (foh,1)
// (denote,1)
// (estimation,1)
// (heels,3)
// (winds,3)
// (sits,5)
// (glow,1)
// (countenance,4)
// (hyrcanian,1)
// (having,2)
// (such,56)
// (ending,1)
// (bounded,1)
// (offences,2)
// (declines,1)
// (look,37)
// (contriving,1)
// (gibber,1)
// (land,5)
// (matin,1)
// (planets,1)
// (cowards,1)
// (hides,1)
// (study,1)
// (switzers,1)
// (plot,1)
// (feeds,1)
// (bernardo,9)
// (romage,1)
// (ugly,1)
// (duppd,1)
// (thralld,1)
// (eats,2)
// (huggermugger,1)
// (piteous,3)
// (heaven,45)
// (practice,4)
// (attractive,1)
// (afterwards,1)
// (danskers,1)
// (shatter,1)
// (christian,5)
// (unsinewd,1)
// (all,123)
// (incensed,1)
// (distracted,4)
// (written,1)
// (though,24)
// (betimes,1)
// (bodkin,1)
// (unpeg,1)
// (ponderous,1)
// (boarded,1)
// (seduce,1)
// (shrouding,1)
// (wittingly,2)
// (superfluous,1)
// (groan,1)
// (girdle,1)
// (black,8)
// (trick,3)
// (digested,1)
// (clear,1)
// (watchd,1)
// (plunge,1)
// (gentry,2)
// (speaks,6)
// (battery,1)
// (lodge,1)
// (forth,6)
// (tellus,1)
// (distinguish,1)
// (about,18)
// (imminent,2)
// (least,2)
// (william,1)
// (merriment,1)
// (thereon,1)
// (ophelias,1)
// (poll,1)
// (distant,1)
// (allowd,2)
// (ask,2)
// (abuses,1)
// (germane,1)
// (before,22)
// (stay,12)
// (sequel,1)
// (sure,9)
// (trivial,1)
// (colours,1)
// (desperate,4)
// (havior,1)
// (top,7)
// (bird,2)
// (pebbles,1)
// (wine,2)
// (feats,1)
// (deprive,1)
// (hamlet,107)
// (special,3)
// (remiss,1)
// (buzzers,1)
// (crimes,3)
// (moderate,1)
// (slips,1)
// (deminaturd,1)
// (senseless,2)
// (wrongd,2)
// (gravemaker,2)
// (impart,5)
// (healthful,1)
// (tumbled,1)
// (armed,2)
// (whale,2)
// (assure,1)
// (tent,1)
// (argal,3)
// (remembrance,4)
// (daggers,2)
// (mouthd,1)
// (sphere,1)
// (gods,6)
// (mount,2)
// (havoc,1)
// (quietly,1)
// (essentially,1)
// (commission,5)
// (womb,1)
// (wheel,3)
// (bless,3)
// (method,2)
// (flat,3)
// (shrillsounding,1)
// (infect,1)
// (sheet,1)
// (pleasd,2)
// (choler,2)
// (horse,3)
// (break,8)
// (hid,2)
// (quintessence,1)
// (usurp,1)
// (dismay,1)
// (ift,3)
// (drop,1)
// (rendezvous,1)
// (slender,1)
// (frighted,1)
// (determination,1)
// (forgot,5)
// (burning,2)
// (enlargd,1)
// (hams,1)
// (bubbles,1)
// (fly,5)
// (eastward,1)
// (orb,1)
// (sinews,2)
// (thews,1)
// (oerraught,1)
// (gently,1)
// (difference,2)
// (golden,3)
// (fitting,1)
// (pieces,1)
// (gleand,1)
// (once,19)
// (eggshell,1)
// (beats,1)
// (grapple,2)
// (sullies,1)
// (pleasing,1)
// (coznage,1)
// (hat,5)
// (whether,6)
// (sadly,1)
// (imaginations,1)
// (fill,2)
// (crowners,1)
// (advantage,1)
// (synod,1)
// (worm,3)
// (bespeak,1)
// (minds,4)
// (askd,1)
// (robustious,1)
// (strutted,1)
// (mouse,2)
// (whips,2)
// (officers,2)
// (venom,2)
// (counsel,3)
// (harlots,1)
// (borrowing,1)
// (daily,1)
// (conceit,5)
// (neighbour,1)
// (opd,1)
// (equivocation,1)
// (sets,2)
// (wittenberg,4)
// (newborn,1)
// (thereto,1)
// (leads,1)
// (comma,1)
// (both,35)
// (marvel,1)
// (soldiers,7)
// (red,2)
// (debate,1)
// (haste,12)
// (profound,2)
// (tenants,1)
// (pester,1)
// (encumbred,1)
// (unusd,1)
// (apoplexd,1)
// (save,5)
// (adulterate,1)
// (beam,1)
// (gaming,3)
// (halt,1)
// (wrung,1)
// (plays,2)
// (witch,1)
// (gather,3)
// (mightier,1)
// (sequent,1)
// (polonius,36)
// (ont,8)
// (peak,1)
// (ho,14)
// (shameful,1)
// (rhenish,2)
// (vouch,1)
// (huge,1)
// (knife,1)
// (seafight,1)
// (coagulate,1)
// (tribute,2)
// (twelve,5)
// (try,6)
// (intents,1)
// (gib,1)
// (dry,3)
// (weasel,2)
// (disasters,1)
// (inquire,1)
// (lived,1)
// (oertook,1)
// (button,1)
// (shoe,1)
// (murtherer,3)
// (moon,5)
// (utter,1)
// (hellish,1)
// (sharp,1)
// (ingenious,1)
// (belike,2)
// (tenantless,1)
// (profit,3)
// (companies,1)
// (shortens,1)
// (forthwith,1)
// (petition,1)
// (lose,7)
// (converted,1)
// (exclaim,1)
// (found,5)
// (mark,15)
// (jigmaker,1)
// (hence,4)
// (conclusions,1)
// (marriages,1)
// (vain,1)
// (receive,7)
// (claudius,2)
// (share,1)
// (lender,1)
// (highly,1)
// (violets,2)
// (int,12)
// (sheets,1)
// (tannd,1)
// (opposites,1)
// (ours,2)
// (lunacies,1)
// (adjoind,1)
// (proper,2)
// (plausive,1)
// (straight,4)
// (maimed,1)
// (moist,1)
// (fathers,20)
// (maiden,2)
// (key,1)
// (hits,3)
// (you,554)
// (slanders,1)
// (toppd,1)
// (my,520)
// (cannot,29)
// (didst,4)
// (yes,5)
// (oerthrown,1)
// (indued,1)
// (shipwrights,1)
// (afraid,1)
// (arithmetic,1)
// (another,13)
// (looks,8)
// (wait,2)
// (potency,1)
// (a,558)
// (cloes,1)
// (above,4)
// (foe,2)
// (herself,6)
// (sith,3)
// (caesar,2)
// (whit,1)
// (scent,1)
// (heyday,1)
// (serpent,2)
// (conjoind,1)
// (swornt,1)
// (sty,1)
// (know,74)
// (giving,3)
// (honours,2)
// (platform,4)
// (fine,10)
// (ice,2)
// (gestures,1)
// (sadness,1)
// (gold,1)
// (mope,1)
// (bring,12)
// (fed,2)
// (nay,26)
// (loam,2)
// (craft,2)
// (sword,17)
// (win,3)
// (honey,1)
// (mildewd,1)
// (brevity,1)
// (wrinkled,1)
// (friends,20)
// (expend,1)
// (where,54)
// (names,1)
// (cease,1)
// (doomsday,3)
// (were,27)
// (adventurous,1)
// (unaneld,1)
// (loathsome,1)
// (sigh,4)
// (acquire,1)
// (unreclaimed,1)
// (th,72)
// (beauteous,1)
// (point,6)
// (mould,1)
// (stop,4)
// (knight,1)
// (gambol,1)
// (mouth,6)
// (flashes,1)
// (gentle,5)
// (denmark,23)
// (unequal,1)
// (harrows,1)
// (packing,1)
// (yours,6)
// (hies,1)
// (breaks,2)
// (fares,2)
// (courtesy,1)
// (stubborn,1)
// (afar,2)
// (marry,16)
// (noted,1)
// (fines,2)
// (claim,1)
// (through,9)
// (often,3)
// (yourself,15)
// (profanely,1)
// (could,32)
// (impotent,1)
// (arms,10)
// (ay,38)
// (unskilful,1)
// (grace,13)
// (steps,1)
// (carp,1)
// (rashness,1)
// (roses,1)
// (herein,4)
// (foreign,1)
// (qualifies,1)
// (malicious,2)
// (assail,1)
// (marss,1)
// (endeavour,1)
// (table,7)
// (witchcraft,2)
// (went,5)
// (boys,1)
// (blood,19)
// (right,11)
// (this,300)
// (marvellous,1)
// (trumpets,3)
// (sinners,1)
// (twixt,2)
// (nave,1)
// (answerd,1)
// (mining,1)
// (bells,1)
// (speeches,1)
// (tutor,1)
// (obsequies,1)
// (canonizd,1)
// (field,1)
// (reechy,1)
// (nemean,1)
// (disappointed,1)
// (otherwise,3)
// (caught,2)
// (bow,3)
// (castle,15)
// (brainish,1)
// (slaves,1)
// (leaves,4)
// (springe,1)
// (wears,2)
// (go,71)
// (defend,3)
// (penetrable,1)
// (bestowd,2)
// (complexion,3)
// (dignity,2)
// (bruit,1)
// (toil,1)
// (whisper,2)
// (mock,4)
// (ungalled,1)
// (blank,2)
// (precious,2)
// (fatness,1)
// (incensd,2)
// (second,11)
// (amazement,2)
// (consent,4)
// (contagious,1)
// (horrid,2)
// (finds,3)
// (advise,1)
// (whatsoever,1)
// (brow,3)
// (emphasis,1)
// (enter,73)
// (borrower,1)
// (avouch,1)
// (draughts,1)
// (fretful,1)
// (stonish,1)
// (fortunes,7)
// (oerteemed,1)
// (something,14)
// (intend,1)
// (kings,9)
// (conveyances,1)
// (lethe,1)
// (lay,9)
// (baby,2)
// (apart,2)
// (entertainment,4)
// (fellies,1)
// (yon,1)
// (porpentine,1)
// (assurd,2)
// (high,3)
// (loneliness,1)
// (wannd,1)
// (came,9)
// (entreated,1)
// (friendship,1)
// (hour,8)
// (twentieth,1)
// (dark,1)
// (one,47)
// (steals,1)
// (observation,1)
// (hic,1)
// (twice,4)
// (whensoever,1)
// (movd,1)
// (feature,2)
// (orbed,1)
// (enemies,2)
// (truant,2)
// (towring,1)
// (thout,1)
// (opposition,2)
// (standing,1)
// (from,95)
// (taint,1)
// (well,90)
// (open,2)
// (defeated,1)
// (nowhere,1)
// (weight,1)
// (condolement,1)
// (quarterd,1)
// (laying,2)
// (vow,2)
// (nowadays,1)
// (further,12)
// (souls,6)
// (raven,1)
// (virtues,2)
// (usurpst,1)
// (passage,3)
// (remain,2)
// (ere,12)
// (business,11)
// (buy,1)
// (norway,13)
// (lowest,1)
// (kick,1)
// (containing,1)
// (gravemakers,1)
// (last,14)
// (whiff,1)
// (forgotten,1)
// (spoke,2)
// (calmly,1)
// (despite,1)
// (trial,2)
// (stays,1)
// (gules,1)
// (gates,1)
// (abstract,1)
// (swoopstake,1)
// (access,1)
// (vulcans,1)
// (ocean,1)
// (blown,2)
// (office,1)
// (swords,1)
// (hands,11)
// (ravel,1)
// (savageness,1)
// (brothel,1)
// (worser,1)
// (uttred,1)
// (counterfeit,1)
// (controversy,1)
// (cudgel,1)
// (receives,1)
// (cleave,1)
// (forgive,2)
// (garb,1)
// (instantly,1)
// (paces,1)
// (ambassadors,6)
// (haviour,1)
// (traitorous,1)
// (judgment,8)
// (its,1)
// (dawning,1)
// (bread,1)
// (tear,3)
// (warms,1)
// (poland,3)
// (threatning,1)
// (intruding,1)
// (imputation,1)
// (several,1)
// (robe,1)
// (equal,2)
// (we,140)
// (sixteen,1)
// (kettledrums,1)
// (polack,4)
// (fetch,2)
// (reply,2)
// (greatness,1)
// (occurrents,1)
// (inexplicable,1)
// (smile,2)
// (sings,14)
// (gonzagos,1)
// (parle,1)
// (whence,1)
// (out,54)
// (herod,1)
// (entreaty,2)
// (quills,1)
// (ignorance,3)
// (locks,1)
// (directions,1)
// (little,18)
// (inventors,1)
// (fierce,1)
// (free,10)
// (matters,2)
// (pour,1)
// (affairs,1)
// (haps,1)
// (mandate,1)
// (quarrelling,1)
// (forestall,1)
// (enemy,3)
// (churchyards,1)
// (tributary,1)
// (twill,4)
// (dumb,6)
// (breadth,1)
// (flatter,1)
// (appeareth,1)
// (ii,6)
// (wise,2)
// (purchases,1)
// (v,3)
// (whord,1)
// (seasons,1)
// (ist,18)
// (pipe,3)
// (dagger,1)
// (abominably,1)
// (pity,4)
// (fawning,1)
// (film,1)
// (yond,1)
// (fight,3)
// (stalks,1)
// (earth,24)
// (loosed,1)
// (hung,1)
// (cloak,1)
// (bark,1)
// (is,346)
// (oercrows,1)
// (trappings,1)
// (beauty,6)
// (sables,2)
// (level,2)
// (pins,1)
// (am,56)
// (birds,1)
// (anchors,1)
// (extolment,1)
// (disclose,1)
// (adoption,1)
// (loan,1)
// (beetles,1)
// (unpregnant,1)
// (blurs,1)
// (likely,1)
// (sport,3)
// (slightly,2)
// (question,16)
// (provoke,1)
// (contagion,2)
// (fallingoff,1)
// (bowl,1)
// (mason,2)
// (lesson,1)
// (discovery,1)
// (extant,1)
// (withdrew,1)
// (borne,3)
// (world,25)
// (wherein,8)
// (us,70)
// (lovingly,1)
// (peating,1)
// (carriage,1)
// (bands,2)
// (due,1)
// (impotence,1)
// (gropd,1)
// (discomfort,1)
// (obligation,2)
// (sorrow,6)
// (stubbornness,1)
// (uses,3)
// (perceivd,1)
// (expressd,1)
// (repugnant,1)
// (feeling,3)
// (residence,1)
// (capable,2)
// (heavens,8)
// (blaze,1)
// (thinkt,1)
// (beer,1)
// (awork,1)
// (trifle,1)
// (employment,2)
// (abstinence,1)
// (forehead,2)
// (dearest,2)
// (shuffling,2)
// (unmatchd,1)
// (princes,1)
// (insolence,1)
// (delays,1)
// (willow,1)
// (outlive,1)
// (hoo,1)
// (hear,32)
// (vantage,2)
// (lover,1)
// (wart,1)
// (brother,9)
// (repel,1)
// (conjuration,1)
// (themselves,5)
// (botch,1)
// (courtiers,2)
// (plain,1)
// (chough,1)
// (until,1)
// (mighty,1)
// (prophesy,2)
// (smeard,1)
// (combat,1)
// (wind,11)
// (hereafter,1)
// (die,7)
// (petar,1)
// (saws,1)
// (acquaint,1)
// (tetter,1)
// (moods,1)
// (chiefly,1)
// (survivor,1)
// (constant,1)
// (alls,2)
// (evenchristen,1)
// (faith,16)
// (porches,1)
// (adheres,1)
// (levies,2)
// (rages,1)
// (uttrance,1)
// (rue,2)
// (happy,3)
// (test,1)
// (hecuba,4)
// (surrender,1)
// (capape,1)
// (matrons,1)
// (darkest,1)
// (temperately,1)
// (few,3)
// (believe,19)
// (osr,25)
// (tickle,1)
// (requiem,1)
// (wit,5)
// (bear,15)
// (eil,1)
// (deny,2)
// (sees,2)
// (thank,9)
// (potent,2)
// (instances,1)
// (bethought,1)
// (knees,2)
// (done,22)
// (expectancy,1)
// (awhile,10)
// (won,1)
// (search,1)
// (recover,3)
// (figure,5)
// (proud,3)
// (summons,1)
// (stopping,1)
// (worse,3)
// (fits,2)
// (variable,2)
// (countries,1)
// (head,25)
// (incestuous,4)
// (reason,14)
// (revel,1)
// (delver,1)
// (want,2)
// (protestation,1)
// (cat,1)
// (diligence,1)
// (questionable,1)
// (shalt,5)
// (foil,2)
// (hast,16)
// (stream,1)
// (abuse,1)
// (return,5)
// (compass,1)
// (een,11)
// (officer,3)
// (fare,6)
// (prate,1)
// (repose,1)
// (girl,1)
// (brain,6)
// (capital,2)
// (fighting,2)
// (wormwood,2)
// (enviously,1)
// (died,4)
// (mineral,1)
// (offenders,1)
// (blench,1)
// (moment,2)
// (fain,4)
// (knaves,1)
// (increase,1)
// (close,3)
// (precisely,1)
// (able,1)
// (escape,2)
// (picture,2)
// (scuffling,1)
// (permanent,1)
// (outherods,1)
// (flesh,5)
// (turnd,4)
// (jelly,1)
// (stone,2)
// (heel,2)
// (hart,1)
// (understanding,3)
// (finding,3)
// (circumvent,1)
// (these,47)
// (muddied,1)
// (notes,1)
// (him,197)
// (sore,3)
// (holds,5)
// (gentleman,16)
// (worth,3)
// (beyond,2)
// (uphoarded,1)
// (drab,1)
// (deceivd,1)
// (army,2)
// (sweat,2)
// (gis,1)
// (infallibly,1)
// (tomorrow,4)
// (becomes,3)
// (purposes,3)
// (nerve,1)
// (stars,4)
// (ungartred,1)
// (providence,2)
// (promisd,2)
// (carouses,1)
// (deep,4)
// (suffred,1)
// (assays,1)
// (nearer,2)
// (anything,5)
// (smart,1)
// (privy,1)
// (malhecho,1)
// (grating,1)
// (airy,1)
// (loud,3)
// (errors,1)
// (infects,1)
// (blackest,1)
// (school,1)
// (held,2)
// (tokens,1)
// (tenders,3)
// (employ,1)
// (sustain,1)
// (oppressd,1)
// (bed,11)
// (observe,3)
// (broke,2)
// (list,7)
// (aloof,2)
// (tragedy,3)
// (ah,3)
// (surely,1)
// (trains,1)
// (warrnt,1)
// (gore,1)
// (peep,2)
// (bastard,1)
// (fie,5)
// (sledded,1)
// (pendant,1)
// (sons,2)
// (sayst,2)
// (companions,1)
// (rebellion,1)
// (seeks,2)
// (jig,2)
// (run,2)
// (dane,6)
// (illusion,1)
// (grinning,1)
// (fall,9)
// (dove,2)
// (bewept,1)
// (mend,1)
// (primy,1)
// (ratified,1)
// (crawling,1)
// (ancient,1)
// (liferendring,1)
// (bonny,1)
// (outstretchd,1)
// (pearl,1)
// (below,3)
// (hum,2)
// (sound,7)
// (squeak,1)
// (sheepskins,1)
// (call,22)
// (sometime,3)
// (bade,1)
// (hopd,1)
// (comfort,1)
// (pickd,1)
// (carrion,1)
// (lazarlike,1)
// (contrary,1)
// (coted,1)
// (hangers,3)
// (sleep,12)
// (posset,1)
// (escoted,1)
// (pestilence,1)
// (recovery,1)
// (serves,2)
// (sorts,1)
// (jealousy,2)
// (pyrrhus,10)
// (leaping,1)
// (image,4)
// (married,3)
// (forms,3)
// (wouldst,6)
// (opposing,1)
// (unseen,3)
// (conveyance,1)
// (priests,1)
// (immortal,1)
// (reigns,1)
// (byr,2)
// (lapwing,1)
// (shove,1)
// (flush,1)
// (unyoke,1)
// (mistress,3)
// (dull,6)
// (any,12)
// (appointment,1)
// (remorseless,1)
// (breast,1)
// (scorns,1)
// (strict,2)
// (beggar,3)
// (deliver,2)
// (offend,1)
// (bodykins,1)
// (speedy,1)
// (nephew,3)
// (contract,1)
// (trialthe,1)
// (wed,3)
// (winking,1)
// (hover,1)
// (else,18)
// (longed,1)
// (see,45)
// (bated,1)
// (alas,10)
// (pooh,1)
// (revengeful,1)
// (favours,2)
// (does,26)
// (million,1)
// (oergrowth,1)
// (parts,3)
// (wicked,6)
// (ear,17)
// (galls,2)
// (origin,2)
// (attendant,5)
// (galld,1)
// (lookd,4)
// (glass,2)
// (welltook,1)
// (aha,2)
// (tormenting,1)
// (voltemand,6)
// (humble,1)
// (sir,75)
// (pol,86)
// (hazard,1)
// (ass,5)
// (candied,1)
// (gaingiving,1)
// (fortified,1)
// (heedful,1)
// (axe,2)
// (needful,1)
// (rhymd,1)
// (assayd,1)
// (margent,1)
// (yaughan,1)
// (lien,1)
// (justice,1)
// (sat,1)
// (lays,1)
// (kisses,3)
// (undertakings,1)
// (opposed,1)
// (iii,4)
// (dwelling,1)
// (unite,1)
// (aid,1)
// (strife,1)
// (circumstances,1)
// (finger,1)
// (form,13)
// (fruitful,1)
// (pale,8)
// (dismal,2)
// (whiles,2)
// (flourish,8)
// (conference,1)
// (assistant,2)
// (despisd,1)
// (flats,1)
// (duty,13)
// (upspring,1)
// (sizd,1)
// (impious,1)
// (flames,2)
// (fellows,4)
// (russet,1)
// (scholar,1)
// (treason,5)
// (checking,1)
// (cautel,1)
// (implorators,1)
// (mousetrap,1)
// (calamity,1)
// (baptista,1)
// (thirties,1)
// (redeliver,2)
// (town,1)
// (desirous,1)
// (even,23)
// (morrow,1)
// (b,4)
// (capons,1)
// (defence,2)
// (day,21)
// (kill,4)
// (spades,1)
// (israel,1)
// (joyfully,1)
// (total,1)
// (thorns,1)
// (affrighted,1)
// (antiquity,1)
// (ability,1)
// (shows,8)
// (manners,2)
// (rood,1)
// (undo,1)
// (warranty,1)
// (adieu,8)
// (monday,1)
// (oppression,1)
// (lash,1)
// (now,98)
// (set,22)
// (remedy,1)
// (fire,12)
// (ignorant,3)
// (body,17)
// (idle,3)
// (prepard,1)
// (spent,1)
// (incest,1)
// (friending,1)
// (death,37)
// (pair,2)
// (mothers,7)
// (render,1)
// (pronouncd,2)
// (zone,1)
// (bulk,2)
// (distraction,2)
// (appetite,1)
// (law,7)
// (judges,1)
// (yesternight,1)
// (rank,7)
// (wrap,1)
// (graveness,1)
// (knowledge,1)
// (function,1)
// (satirical,1)
// (imagine,1)
// (se,1)
// (broad,2)
// (weedy,1)
// (sleeps,4)
// (hail,1)
// (near,11)
// (means,20)
// (bakd,2)
// (bearing,1)
// (eager,2)
// (pocky,1)
// (foolery,1)
// (miraculous,1)
// (stuff,3)
// (transform,1)
// (heard,14)
// (think,47)
// (conjectures,1)
// (touches,1)
// (buttons,1)
// (rapier,3)
// (gum,1)
// (paintings,1)
// (sable,2)
// (bawdry,1)
// (till,20)
// (unfellowed,1)
// (oerhasty,1)
// (o,124)
// (oft,12)
// (moreover,1)
// (narrow,1)
// (woo,1)
// (somethingsettled,1)
// (clamour,1)
// (pelion,1)
// (ladys,1)
// (unmannerly,1)
// (distemper,3)
// (sickness,2)
// (twain,2)
// (stale,1)
// (freely,4)
// (cost,2)
// (toomuch,1)
// (winner,1)
// (blanket,1)
// (terms,5)
// (realm,1)
// (passing,3)
// (shocks,1)
// (respects,1)
// (c,1)
// (mincing,1)
// (overlookd,1)
// (cast,6)
// (issue,2)
// (prescripts,1)
// (neither,10)
// (carries,1)
// (cheerfully,2)
// (dismantled,1)
// (livery,3)
// (scullion,1)
// (soil,2)
// (answers,1)
// (half,5)
// (seed,1)
// (sovereignty,1)
// (imperious,1)
// (gain,2)
// (visage,5)
// (pangs,1)
// (started,1)
// (blasts,1)
// (grew,1)
// (mine,31)
// (younger,1)
// (smoothness,1)
// (barrd,1)
// (lack,6)
// (words,20)
// (unrighteous,1)
// (combined,1)
// (arras,6)
// (majesty,16)
// (mean,11)
// (priest,4)
// (digs,1)
// (primrose,1)
// (raves,1)
// (nonce,1)
// (quality,4)
// (vailed,1)
// (gins,1)
// (budge,1)
// (signify,2)
// (aye,1)
// (model,1)
// (filial,1)
// (clown,36)
// (knotted,1)
// (jointly,1)
// (horridly,2)
// (hitherto,2)
// (lighted,1)
// (colleagued,1)
// (perturbed,1)
// (reform,1)
// (nose,2)
// (admit,2)
// (known,8)
// (defeat,2)
// (spacious,1)
// (speechless,1)
// (help,12)
// (took,4)
// (meet,9)
// (service,8)
// (drift,4)
// (enquire,1)
// (remorse,1)
// (define,1)
// (appliance,1)
// (afflict,1)
// (taken,3)
// (calm,2)
// (leans,1)
// (fortune,11)
// (reputation,1)
// (turn,7)
// (queens,1)
// (keen,2)
// (tweaks,1)
// (pursuest,1)
// (heavy,6)
// (news,10)
// (withal,6)
// (pro,1)
// (hears,3)
// (labour,2)
// (name,11)
// (airs,1)
// (anticipation,1)
// (follow,21)
// (strong,4)
// (weaker,1)
// (thereof,1)
// (wills,1)
// (warlike,5)
// (skull,10)
// (tropically,1)
// (grown,4)
// (lap,2)
// (wisdom,7)
// (especially,2)
// (wonderwounded,1)
// (somever,1)
// (absurd,2)
// (err,1)
// (pledge,1)
// (trespass,1)
// (timberd,1)
// (methinks,5)
// (freeze,1)
// (ber,20)
// (spurns,2)
// (mightyyou,1)
// (stealers,1)
// (cue,1)
// (than,50)
// (rant,1)
// (deeply,1)
// (remainder,1)
// (next,5)
// (espials,1)
// (knowing,2)
// (hourly,1)
// (ranker,2)
// (wish,3)
// (hollow,1)
// (preceding,1)
// (wildness,1)
// (company,1)
// (offended,3)
// (polacks,1)
// (gauntlets,1)
// (tedious,2)
// (hand,18)
// (great,26)
// (scenes,1)
// (lordship,8)
// (countrys,1)
// (whom,6)
// (shown,2)
// (rests,2)
// (calls,4)
// (portentous,1)
// (curiously,1)
// (marble,1)
// (procession,1)
// (beguile,2)
// (theme,3)
// (lying,1)
// (the,1090)
// (ghost,34)
// (crescent,1)
// (sends,4)
// (crew,2)
// (guil,29)
// (quillets,1)
// (grizzled,1)
// (not,315)
// (gavet,1)
// (shovel,1)
// (continual,1)
// (sundays,1)
// (nasty,1)
// (pranks,1)
// (lasts,1)
// (strew,1)
// (cherub,1)
// (revengd,3)
// (delight,3)
// (provided,1)
// (softly,1)
// (chief,3)
// (summit,2)
// (paris,1)
// (falling,1)
// (discourse,6)
// (aright,1)
// (pitied,1)
// (youll,3)
// (distemperd,1)
// (eloquent,1)
// (unsanctified,1)
// (brothers,9)
// (doctor,1)
// (account,1)
// (inhibition,1)
// (cesse,1)
// (curls,1)
// (patient,3)
// (king,196)
// (seemingvirtuous,1)
// (exploit,1)
// (collected,2)
// (departed,1)
// (hoist,1)
// (trip,1)
// (assault,1)
// (termagant,1)
// (meed,1)
// (thinkst,1)
// (chameleons,1)
// (neglected,2)
// (possible,4)
// (naught,2)
// (against,24)
// (et,1)
// (precurse,1)
// (imperial,1)
// (whilst,3)
// (meaning,1)
// (furnish,1)
// (abhorred,1)
// (hours,2)
// (trifling,1)
// (shrunk,1)
// (union,2)
// (unforcd,1)
// (nunnery,5)
// (deaths,1)
// (cracks,1)
// (face,11)
// (wholesome,7)
// (stithy,1)
// (mazzard,1)
// (stooping,1)
// (sweets,1)
// (cunnings,1)
// (1,6)
// (living,2)
// (roughhew,1)
// (besmirch,1)
// (statists,1)
// (use,16)
// (religion,1)
// (stood,6)
// (cum,1)
// (fiends,1)
// (s,1)
// (white,4)
// (showers,1)
// (splenitive,1)
// (chariest,1)
// (beget,1)
// (shortly,4)
// (heraldry,2)
// (reveal,1)
// (backward,1)
// (suspiration,1)
// (more,95)
// (impond,2)
// (staind,1)
// (height,1)
// (virgin,1)
// (distilment,1)
// (must,61)
// (unsatisfied,1)
// (besides,1)
// (kingdom,5)
// (nightgown,1)
// (belief,1)
// (highness,1)
// (nights,4)
// (opinions,2)
// (massy,1)
// (excuse,1)
// (particular,8)
// (weep,4)
// (murtherd,1)
// (faults,3)
// (traducd,1)
// (forfeit,1)
// (auspicious,1)
// (rend,1)
// (i,577)
// (knew,5)
// (divide,2)
// (crier,1)
// (volt,2)
// (draggd,1)
// (mars,1)
// (yielding,1)
// (ambition,6)
// (cloud,1)
// (harbingers,1)
// (which,64)
// (masters,4)
// (courteous,1)
// (voyage,2)
// (smelling,1)
// (should,56)
// (knave,5)
// (insert,1)
// (ears,9)
// (placed,1)
// (her,91)
// (court,6)
// (race,1)
// (beaver,1)
// (put,24)
// (scarfd,1)
// (abroad,1)
// (sum,1)
// (poisons,1)
// (auntmother,1)
// (kills,3)
// (laboursome,1)
// (quit,2)
// (walkd,1)
// (favourite,1)
// (persuade,1)
// (suiting,1)
// (familiar,1)
// (harping,1)
// (upon,55)
// (patch,2)
// (piece,7)
// (helps,1)
// (anothers,1)
// (springs,1)
// (struggling,1)
// (first,19)
// (bedrid,1)
// (malefactions,1)
// (opinion,1)
// (morning,5)
// (observant,1)
// (crack,1)
// (artless,1)
// (just,2)
// (sterling,1)
// (already,6)
// (sallets,1)
// (stirrd,1)
// (strewments,1)
// (counsellor,1)
// (drive,2)
// (pole,2)
// (pound,1)
// (roughly,2)
// (winters,1)
// (heavyheaded,1)
// (guarded,1)
// (waits,1)
// (fool,7)
// (hyperion,1)
// (quest,1)
// (investments,1)
// (peace,10)
// (thereunto,1)
// (feet,2)
// (how,90)
// (swearing,2)
// (confound,2)
// (envenomd,2)
// (abatements,1)
// (there,77)
// (thither,3)
// (ambiguous,1)
// (dearth,1)
// (scape,2)
// (liege,3)
// (overcame,1)
// (parchment,1)
// (rosemary,1)
// (stuck,1)
// (capability,1)
// (affectation,1)
// (enterprises,1)
// (arraign,1)
// (camel,2)
// (woodcocks,1)
// (dye,1)
// (conjunctive,1)
// (wantonness,1)
// (oerhear,1)
// (clothes,1)
// (soles,1)
// (round,6)
// (plumtree,1)
// (howsoever,1)
// (passeth,1)
// (fault,5)
// (estate,3)
// (play,45)
// (asunder,1)
// (moons,1)
// (joint,1)
// (waist,1)
// (burns,2)
// (whirlwind,1)
// (prize,1)
// (glimpses,1)
// (aside,19)
// (damn,1)
// (writes,1)
// (perdy,1)
// (bare,1)
// (warning,1)
// (mines,1)
// (retires,1)
// (goblins,1)
// (wont,3)
// (fortifications,1)
// (forgery,1)
// (remembrances,1)
// (unsmirched,1)
// (disease,1)
// (other,28)
// (boughs,1)
// (spur,1)
// (relative,1)
// (weighing,1)
// (tragedians,1)
// (recount,1)
// (flowers,3)
// (kingly,1)
// (mortisd,1)
// (delivered,1)
// (attent,1)
// (plautus,1)
// (glowworm,1)
// (marriage,6)
// (libertine,1)
// (ye,4)
// (hearsed,1)
// (repulsed,1)
// (calf,1)
// (dominions,1)
// (will,172)
// (beautified,2)
// (neer,3)
// (trade,2)
// (yeomans,1)
// (fish,2)
// (thousand,11)
// (flagons,1)
// (child,2)
// (eruption,1)
// (unsure,1)
// (arrivd,1)
// (waves,3)
// (stately,1)
// (reckless,1)
// (whippd,1)
// (forbid,2)
// (beware,2)
// (faculties,2)
// (farm,2)
// (almost,10)
// (calves,1)
// (ourselves,13)
// (drunkards,1)
// (himself,21)
// (ducats,3)
// (batten,1)
// (betterd,1)
// (door,5)
// (props,1)
// (groans,1)
// (purport,1)
// (mayst,1)
// (sprinkle,1)
// (under,5)
// (thaw,1)
// (bakers,1)
// (reading,2)
// (health,6)
// (approaches,1)
// (proceed,2)
// (validity,1)
// (crowns,1)
// (device,1)
// (case,1)
// (queen,120)
// (have,183)
// (waving,1)
// (careless,1)
// (beggard,1)
// (express,3)
// (saviours,1)
// (purging,2)
// (dreadfully,1)
// (prolongs,1)
// (comart,1)
// (thing,18)
// (willing,2)
// (losing,1)
// (ceremony,3)
// (pride,1)
// (forgeries,1)
// (drownd,7)
// (inclination,2)
// (groundlings,1)
// (niggard,1)
// (borrowed,1)
// (suchaone,1)
// (immediately,1)
// (scrimers,1)
// (breathes,1)
// (answer,14)
// (step,2)
// (accord,1)
// (peevish,1)
// (widow,1)
// (stones,1)
// (beasts,2)
// (gibes,1)
// (address,1)
// (sanity,1)
// (pigeonliverd,1)
// (when,56)
// (mutes,2)
// (quarrel,2)
// (prevent,2)
// (strange,9)
// (history,2)
// (proverb,1)
// (build,1)
// (gaged,1)
// (as,227)
// (rebellious,2)
// (waste,1)
// (heavily,1)
// (mercy,4)
// (window,1)
// (replication,1)
// (joy,8)
// (tree,1)
// (forgd,1)
// (holla,1)
// (earnest,1)
// (meats,1)
// (calumnious,1)
// (fulfilld,1)
// (shapes,3)
// (inheritor,1)
// (oerrule,1)
// (repent,3)
// (ungracious,1)
// (board,1)
// (crook,1)
// (beteem,1)
// (space,1)
// (sides,3)
// (revenge,12)
// (bestow,4)
// (hardy,1)
// (convey,1)
// (faction,1)
// (short,5)
// (shadow,3)
// (appal,1)
// (week,1)
// (horatio,47)
// (pardon,6)
// (fate,2)
// (stick,3)
// (overcome,1)
// (bunghole,1)
// (christians,1)
// (ostentation,1)
// (aspect,1)
// (bodies,5)
// (dig,2)
// (trophies,1)
// (imagination,4)
// (marvells,1)
// (tarre,1)
// (condole,1)
// (built,1)
// (lost,9)
// (bleed,2)
// (dug,1)
// (unmanly,1)
// (shift,1)
// (liquor,2)
// (enactures,1)
// (paint,1)
// (unpolluted,1)
// (stronger,4)
// (everpreserved,1)
// (toe,2)
// (lids,1)
// (deserve,1)
// (learn,1)
// (men,12)
// (learning,1)
// (uneffectual,1)
// (brood,1)
// (brute,1)
// (turns,1)
// (thoult,1)
// (couch,2)
// (doubt,10)
// (rear,1)
// (praying,1)
// (haply,3)
// (ape,2)
// (scandal,2)
// (push,1)
// (dishes,1)
// (truly,8)
// (lips,2)
// (wilfully,1)
// (arrests,1)
// (droppings,1)
// (grained,1)
// (oerhanging,1)
// (murdring,1)
// (sent,13)
// (captain,3)
// (toy,2)
// (unhappily,1)
// (gainst,4)
// (proclaims,2)
// (bearers,2)
// (differences,1)
// (therefore,15)
// (belovd,1)
// (arm,5)
// (amaze,1)
// (admittance,1)
// (delights,3)
// (goodly,3)
// (wild,4)
// (motion,4)
// (nine,3)
// (house,6)
// (duties,1)
// (milky,1)
// (commanded,1)
// (ease,4)
// (exceed,1)
// (easy,2)
// (quickness,1)
// (man,52)
// (pure,3)
// (copied,1)
// (faded,1)
// (pursued,1)
// (unknown,2)
// (agreeing,1)
// (liquid,1)
// (expostulate,1)
// (reconcilement,1)
// (bawd,1)
// (his,304)
// (suddenly,1)
// (copd,1)
// (habit,4)
// (wrack,1)
// (cleft,1)
// (wot,1)
// (commands,1)
// (indifferent,3)
// (secret,4)
// (embracing,1)
// (fencing,1)
// (comply,2)
// (cap,2)
// (loose,2)
// (readiness,1)
// (usual,1)
// (seem,10)
// (accounted,1)
// (since,17)
// (eyases,1)
// (adowna,1)
// (food,2)
// (goes,14)
// (excrements,1)
// (unto,8)
// (stir,5)
// (answerest,1)
// (money,2)
// (supervise,1)
// (seals,1)
// (wake,1)
// (yet,43)
// (flourishes,1)
// (lapsd,1)
// (thine,14)
// (unprevailing,1)
// (acursing,1)
// (grounds,1)
// (befalln,1)
// (advancement,2)
// (vapours,1)
// (nero,1)
// (with,277)
// (crib,1)
// (pourd,1)
// (best,11)
// (dally,1)
// (jawbone,1)
// (duller,1)
// (struck,6)
// (aliis,1)
// (plague,2)
// (followed,2)
// (melancholy,2)
// (servants,2)
// (mockery,1)
// (tale,4)
// (drinking,1)
// (loses,1)
// (allowance,2)
// (snuff,1)
// (spies,1)
// (delve,1)
// (lasting,2)
// (praise,2)
// (crab,1)
// (goodness,2)
// (temperance,1)
// (pajock,1)
// (nothings,1)
// (fearing,1)
// (says,8)
// (crows,1)
// (remove,2)
// (currents,2)
// (offerd,1)
// (thirty,3)
// (knocking,1)
// (get,9)
// (palm,2)
// (bisson,1)
// (parching,1)
// (adams,1)
// (pelican,1)
// (shakespeare,1)
// (possess,1)
// (father,52)
// (boy,3)
// (weigh,2)
// (farewell,17)
// (wall,1)
// (playing,2)
// (hey,2)
// (prove,3)
// (miss,1)
// (folk,1)
// (callt,1)
// (weary,2)
// (paper,2)
// (rede,1)
// (barefacd,1)
// (dout,1)
// (forgone,1)
// (coach,1)
// (heat,3)
// (carried,1)
// (hypocrites,1)
// (pleasant,1)
// (importunate,1)
// (alleys,1)
// (advice,3)
// (torches,1)
// (sterile,1)
// (chopine,1)
// (alexander,5)
// (achievements,1)
// (cerements,1)
// (babe,1)
// (julius,2)
// (month,4)
// (seated,1)
// (sponge,3)
// (barren,1)
// (lamound,1)
// (shake,2)
// (ended,1)
// (away,25)
// (em,2)
// (incorpsd,1)
// (carbuncles,1)
// (daisy,1)
// (mess,4)
// (yesty,1)
// (minute,1)
// (ham,358)
// (armd,2)
// (reynaldo,6)
// (dispatchd,1)
// (tread,1)
// (implements,1)
// (dust,7)
// (going,3)
// (hole,1)
// (damnable,1)
// (addicted,1)
// (gross,3)
// (givers,1)
// (straws,1)
// (infinite,4)
// (proceeding,1)
// (addition,3)
// (party,1)
// (nony,3)
// (recks,1)
// (blasting,1)
// (truelove,2)
// (curse,1)
// (observance,2)
// (dispatch,2)
// (admiration,3)
// (scale,2)
// (long,17)
// (pardond,2)
// (demanded,1)
// (rivet,1)
// (frenchman,1)
// (accidents,1)
// (grass,1)
// (boistrous,1)
// (certain,4)
// (vanquisher,1)
// (deer,1)
// (trail,2)
// (killd,5)
// (blue,1)
// (continent,2)
// (sick,4)
// (crocodile,1)
// (drunk,1)
// (fadoms,1)
// (attribute,1)
// (gratis,1)
// (rest,14)
// (whet,1)
// (rite,1)
// (bedtime,1)
// (true,22)
// (acting,1)
// (offal,1)
// (corse,3)
// (giantlike,1)
// (owl,1)
// (vigour,1)
// (persons,1)
// (fors,2)
// (knowst,2)
// (translate,2)
// (designd,1)
// (hunts,1)
// (gulf,1)
// (strike,2)
// (perfections,1)
// (curd,1)
// (need,4)
// (blunted,1)
// (oermastert,1)
// (pierce,1)
// (places,1)
// (songs,2)
// (guildenstern,30)
// (low,1)
// (resolutes,1)
// (ossa,1)
// (ourself,3)
// (six,4)
// (three,9)
// (pressures,1)
// (stake,1)
// (frownd,1)
// (blow,3)
// (friend,14)
// (barefoot,1)
// (bestial,1)
// (conscience,8)
// (overdone,2)
// (flattering,1)
// (capitol,1)
// (sun,9)
// (husbands,3)
// (perdition,1)
// (shell,3)
// (asleep,2)
// (taen,2)
// (grunt,1)
// (thats,16)
// (quickly,1)
// (whereto,4)
// (grapples,1)
// (resembles,1)
// (innocent,1)
// (fore,1)
// (blast,2)
// (seagown,1)
// (lean,1)
// (lords,7)
// (placd,2)
// (altitude,1)
// (lodgd,1)
// (cornelius,5)
// (self,1)
// (sipping,1)
// (here,55)
// (flatterd,1)
// (some,53)
// (skirts,1)
// (beds,1)
// (distrust,2)
// (seas,1)
// (dare,6)
// (bedded,1)
// (dozen,2)
// (barkd,1)
// (knockd,1)
// (exercise,2)
// (restraind,1)
// (without,19)
// (welcome,17)
// (undiscoverd,1)
// (fennel,1)
// (affront,1)
// (forts,1)
// (singeing,1)
// (fitness,1)
// (intent,2)
// (too,50)
// (expel,2)
// (ladies,4)
// (tempest,1)
// (mountebank,1)
// (performance,1)
// (beard,6)
// (alack,3)
// (wi,4)
// (thein,1)
// (sextons,1)
// (unsifted,1)
// (nations,1)
// (fiction,1)
// (anon,6)
// (swore,1)
// (horseback,1)
// (enseamed,1)
// (amaking,1)
// (receivd,3)
// (transports,1)
// (shriving,1)
// (cursed,4)
// (monstrous,1)
// (livst,1)
// (society,1)
// (howling,1)
// (divinity,2)
// (into,28)
// (johnadreams,1)
// (scourge,2)
// (colour,5)
// (hatch,1)
// (meditation,1)
// (roscius,1)
// (dram,1)
// (folly,1)
// (appears,2)
// (feard,1)
// (bound,5)
// (replies,1)
// (usd,2)
// (comst,2)
// (maintains,1)
// (cut,2)
// (oblivion,1)
// (instrumental,1)
// (foolish,3)
// (lady,14)
// (pinch,1)
// (possession,1)
// (greatly,1)
// (spirits,5)
// (shirt,1)
// (laid,6)
// (hire,1)
// (vile,5)
// (serious,1)
// (never,26)
// (peasant,2)
// (devoutly,1)
// (precepts,1)
// (motive,5)
// (affections,1)
// (conceive,1)
// (mermaidlike,1)
// (graves,3)
// (embarkd,1)
// (paddock,1)
// (declension,1)
// (quiet,5)
// (vial,1)
// (paragon,1)
// (privates,1)
// (post,2)
// (accidental,1)
// (soeer,1)
// (hang,4)
// (norwegian,1)
// (stranger,1)
// (historicalpastoral,1)
// (audience,5)
// (unpack,1)
// (lawyer,1)
// (rabble,1)
// (hearers,2)
// (feathers,1)
// (noise,10)
// (heroes,1)
// (note,6)
// (invites,1)
// (clawed,1)
// (considered,1)
// (daisies,1)
// (countnance,1)
// (t,7)
// (wings,2)
// (canker,2)
// (maggots,2)
// (portal,1)
// (flash,1)
// (report,5)
// (night,36)
// (reckoning,1)
// (envy,2)
// (chorus,1)
// (offendendo,1)
// (unfold,3)
// (wheaten,1)
// (inch,1)
// (cataplasm,1)
// (flood,1)
// (returnd,4)
// (cold,6)
// (lead,4)
// (slings,1)
// (demands,2)
// (plots,2)
// (pause,4)
// (truepenny,1)
// (dealt,1)
// (flushing,1)
// (dire,1)
// (quarry,1)
// (harmony,1)
// (nobility,1)
// (university,1)
// (worn,1)
// (chamberlain,1)
// (hark,1)
// (winks,1)
// (exterior,1)
// (ecstasy,4)
// (fangd,1)
// (policy,1)
// (line,2)
// (highest,1)
// (chamber,3)
// (lie,10)
// (simple,1)
// (glad,4)
// (tother,1)
// (river,1)
// (bilboes,1)
// (happen,1)
// (unwholesome,1)
// (tyrannically,1)
// (seeming,2)
// (importund,1)
// (lofty,1)
// (dangerous,5)
// (read,5)
// (baseness,1)
// (hue,1)
// (kites,1)
// (late,10)
// (fee,3)
// (met,1)
// (chanson,1)
// (tanner,1)
// (rascal,1)
// (throwing,1)
// (prayers,2)
// (distract,1)
// (respect,2)
// (unless,3)
// (beart,1)
// (perpend,1)
// (nephews,2)
// (chase,1)
// (profession,1)
// (coronation,1)
// (willt,1)
// (marshal,1)
// (offence,9)
// (bosom,4)
// (entreatments,1)
// (eat,5)
// (coronet,1)
// (bulwark,1)
// (draw,9)
// (voice,12)
// (defeats,1)
// (ends,2)
// (tis,73)
// (hoar,1)
// (hilts,1)
// (wheres,2)
// (servd,2)
// (tender,4)
// (overpeering,1)
// (perfume,2)
// (riband,1)
// (hillo,1)
// (rash,3)
// (brave,3)
// (myself,12)
// (kin,2)
// (interim,1)
// (tomb,1)
// (loved,2)
// (wick,1)
// (harsh,3)
// (marrow,1)
// (bloat,1)
// (outward,2)
// (conveniently,1)
// (carters,1)
// (painting,1)
// (frost,1)
// (confusion,1)
// (same,12)
// (tried,1)
// (disclaiming,1)
// (wandring,1)
// (uncurrent,1)
// (drum,3)
// (shall,114)
// (live,16)
// (inurnd,1)
// (fair,20)
// (sighs,1)
// (handsaw,1)
// (passions,1)
// (shrewdly,1)
// (calld,2)
// (fruit,2)
// (fairjudgment,1)
// (vision,1)
// (they,101)
// (cross,1)
// (cup,4)
// (denies,1)
// (lucianus,2)
// (throughly,1)
// (teeth,2)
// (importunity,1)
// (subject,3)
// (deed,11)
// (heart,29)
// (cock,6)
// (wounded,1)
// (clemency,1)
// (dread,5)
// (waterfly,1)
// (seafaring,1)
// (mutinies,1)
// (purer,1)
// (bellowed,1)
// (valentine,1)
// (weeds,4)
// (commune,1)
// (faild,1)
// (lust,2)
// (shook,1)
// (puts,5)
// (players,23)
// (sold,1)
// (tells,1)
// (effects,2)
// (pile,1)
// (suffers,3)
// (larded,2)
// (ministring,1)
// (nomination,1)
// (physic,1)
// (tongue,15)
// (behavd,1)
// (pastoral,1)
// (travel,2)
// (cry,5)
// (jest,3)
// (envious,1)
// (obscure,1)
// (peculiar,1)
// (chiefest,1)
// (ban,1)
// (progress,1)
// (triumph,1)
// (sere,1)
// (by,111)
// (path,1)
// (palpable,1)
// (wishd,1)
// (an,56)
// (prithee,6)
// (infusion,1)
// (encorporal,1)
// (wants,2)
// (grossly,1)
// (happiness,1)
// (appear,3)
// (rivals,1)
// (drives,1)
// (woe,8)
// (truncheons,1)
// (ventages,1)
// (vi,1)
// (indirections,1)
// (promise,1)
// (willingly,2)
// (unproportiond,1)
// (lewdness,1)
// (warrant,4)
// (remember,12)
// (depends,2)
// (shroud,1)
// (puffd,2)
// (windy,1)
// (organ,3)
// (beneath,4)
// (mischance,2)
// (bet,1)
// (dogs,1)
// (spade,4)
// (matchd,1)
// (lot,1)
// (provide,1)
// (compound,1)
// (blasted,2)
// (berattle,1)
// (indentures,1)
// (sea,6)
// (take,36)
// (oertop,1)
// (purse,3)
// (trickd,1)
// (obey,7)
// (evermore,1)
// (mountain,3)
// (fiery,3)
// (stayd,3)
// (suit,3)
// (nipping,1)
// (considerd,1)
// (raisd,1)
// (outface,1)
// (liberty,5)
// (turbulent,1)
// (rock,1)
// (aboard,3)
// (sans,1)
// (crown,6)
// (minutes,1)
// (fruits,1)
// (memory,10)
// (beggars,2)
// (work,10)
// (imposthume,1)
// (bellow,1)
// (caution,1)
// (loser,1)
// (actions,2)
// (riotous,1)
// (blessing,5)
// (fond,1)
// (tell,43)
// (animals,1)
// (benetted,1)
// (neutral,1)
// (stoup,1)
// (consequence,4)
// (pirate,1)
// (mobled,3)
// (tennis,1)
// (always,1)
// (hold,29)
// (crimeful,1)
// (abusd,1)
// (angry,1)
// (sailors,3)
// (revels,1)
// (brutus,1)
// (forbear,1)
// (comment,1)
// (passionate,2)
// (being,12)
// (favour,4)
// (compelled,1)
// (tediousness,1)
// (maids,3)
// (cannons,1)
// (gravediggers,1)
// (throat,4)
// (steward,1)
// (quite,4)
// (singeth,1)
// (bringing,1)
// (bevy,1)
// (dido,1)
// (shoes,2)
// (mainly,1)
// (screend,1)
// (term,2)
// (beg,7)
// (clowns,3)
// (dew,3)
// (general,7)
// (region,2)
// (dicers,1)
// (peaceparted,1)
// (unseal,1)
// (yoricks,1)
// (unworthiest,1)
// (still,20)
// (chance,2)
// (clappd,1)
// (shouldst,2)
// (hinds,1)
// (dog,2)
// (enginer,1)
// (heir,1)
// (send,4)
// (elder,1)
// (inventorially,1)
// (fretted,1)
// (pomp,1)
// (croaking,1)
// (hearing,4)
// (damnd,5)
// (wisdoms,1)
// (ministers,1)
// (thou,105)
// (satisfaction,1)
// (lacks,1)
// (shent,1)
// (heartily,3)
// (heavenly,2)
// (wassail,1)
// (defy,1)
// (ruin,1)
// (got,2)
// (deal,1)
// (cunning,4)
// (rhapsody,1)
// (diet,2)
// (can,34)
// (writers,1)
// (pestilent,2)
// (split,1)
// (contents,1)
// (woundless,1)
// (churlish,1)
// (neglect,1)
// (accent,2)
// (daintier,1)
// (husbandry,1)
// (walks,2)
// (stirring,1)
// (none,13)
// (howeer,1)
// (satisfied,1)
// (depart,1)
// (hes,10)
// (brazen,1)
// (lightest,1)
// (sit,8)
// (bitter,3)
// (clays,1)
// (turnst,1)
// (fatted,1)
// (restore,1)
// (desperation,2)
// (natures,3)
// (kneels,2)
// (thoughts,17)
// (ominous,1)
// (vicious,1)
// (corrupted,1)
// (inoculate,1)
// (enmity,1)
// (schoolfellows,1)
// (melt,2)
// (poet,1)
// (weeps,1)
// (messengers,2)
// (suits,3)
// (hate,1)
// (intil,1)
// (diction,1)
// (life,33)
// (scanter,1)
// (prodigal,2)
// (ring,2)
// (madam,12)
// (she,47)
// (whipping,1)
// (dear,29)
// (sending,2)
// (illo,1)
// (personal,1)
// (arrows,2)
// (dallying,1)
// (blazon,1)
// (contrive,2)
// (crowner,1)
// (nobler,1)
// ...
// (crook,1)
// (beteem,1)
// (space,1)
// (sides,3)
// (revenge,12)
// (bestow,4)
// (hardy,1)
// (convey,1)
// (faction,1)
// (short,5)
// (shadow,3)
// (appal,1)
// (week,1)
// (horatio,47)
// (pardon,6)
// (fate,2)
// (stick,3)
// (overcome,1)
// (bunghole,1)
// (christians,1)
// (ostentation,1)
// (aspect,1)
// (bodies,5)
// (dig,2)
// (trophies,1)
// (imagination,4)
// (marvells,1)
// (tarre,1)
// (condole,1)
// (built,1)
// (lost,9)
// (bleed,2)
// (dug,1)
// (unmanly,1)
// (shift,1)
// (liquor,2)
// (enactures,1)
// (paint,1)
// (unpolluted,1)
// (stronger,4)
// (everpreserved,1)
// (toe,2)
// (lids,1)
// (deserve,1)
// (learn,1)
// (men,12)
// (learning,1)
// (uneffectual,1)
// (brood,1)
// (brute,1)
// (turns,1)
// (thoult,1)
// (couch,2)
// (doubt,10)
// (rear,1)
// (praying,1)
// (haply,3)
// (ape,2)
// (scandal,2)
// (push,1)
// (dishes,1)
// (truly,8)
// (lips,2)
// (wilfully,1)
// (arrests,1)
// (droppings,1)
// (grained,1)
// (oerhanging,1)
// (murdring,1)
// (sent,13)
// (captain,3)
// (toy,2)
// (unhappily,1)
// (gainst,4)
// (proclaims,2)
// (bearers,2)
// (differences,1)
// (therefore,15)
// (belovd,1)
// (arm,5)
// (amaze,1)
// (admittance,1)
// (delights,3)
// (goodly,3)
// (wild,4)
// (motion,4)
// (nine,3)
// (house,6)
// (duties,1)
// (milky,1)
// (commanded,1)
// (ease,4)
// (exceed,1)
// (easy,2)
// (quickness,1)
// (man,52)
// (pure,3)
// (copied,1)
// (faded,1)
// (pursued,1)
// (unknown,2)
// (agreeing,1)
// (liquid,1)
// (expostulate,1)
// (reconcilement,1)
// (bawd,1)
// (his,304)
// (suddenly,1)
// (copd,1)
// (habit,4)
// (wrack,1)
// (cleft,1)
// (wot,1)
// (commands,1)
// (indifferent,3)
// (secret,4)
// (embracing,1)
// (fencing,1)
// (comply,2)
// (cap,2)
// (loose,2)
// (readiness,1)
// (usual,1)
// (seem,10)
// (accounted,1)
// (since,17)
// (eyases,1)
// (adowna,1)
// (food,2)
// (goes,14)
// (excrements,1)
// (unto,8)
// (stir,5)
// (answerest,1)
// (money,2)
// (supervise,1)
// (seals,1)
// (wake,1)
// (yet,43)
// (flourishes,1)
// (lapsd,1)
// (thine,14)
// (unprevailing,1)
// (acursing,1)
// (grounds,1)
// (befalln,1)
// (advancement,2)
// (vapours,1)
// (nero,1)
// (with,277)
// (crib,1)
// (pourd,1)
// (best,11)
// (dally,1)
// (jawbone,1)
// (duller,1)
// (struck,6)
// (aliis,1)
// (plague,2)
// (followed,2)
// (melancholy,2)
// (servants,2)
// (mockery,1)
// (tale,4)
// (drinking,1)
// (loses,1)
// (allowance,2)
// (snuff,1)
// (spies,1)
// (delve,1)
// (lasting,2)
// (praise,2)
// (crab,1)
// (goodness,2)
// (temperance,1)
// (pajock,1)
// (nothings,1)
// (fearing,1)
// (says,8)
// (crows,1)
// (remove,2)
// (currents,2)
// (offerd,1)
// (thirty,3)
// (knocking,1)
// (get,9)
// (palm,2)
// (bisson,1)
// (parching,1)
// (adams,1)
// (pelican,1)
// (shakespeare,1)
// (possess,1)
// (father,52)
// (boy,3)
// (weigh,2)
// (farewell,17)
// (wall,1)
// (playing,2)
// (hey,2)
// (prove,3)
// (miss,1)
// (folk,1)
// (callt,1)
// (weary,2)
// (paper,2)
// (rede,1)
// (barefacd,1)
// (dout,1)
// (forgone,1)
// (coach,1)
// (heat,3)
// (carried,1)
// (hypocrites,1)
// (pleasant,1)
// (importunate,1)
// (alleys,1)
// (advice,3)
// (torches,1)
// (sterile,1)
// (chopine,1)
// (alexander,5)
// (achievements,1)
// (cerements,1)
// (babe,1)
// (julius,2)
// (month,4)
// (seated,1)
// (sponge,3)
// (barren,1)
// (lamound,1)
// (shake,2)
// (ended,1)
// (away,25)
// (em,2)
// (incorpsd,1)
// (carbuncles,1)
// (daisy,1)
// (mess,4)
// (yesty,1)
// (minute,1)
// (ham,358)
// (armd,2)
// (reynaldo,6)
// (dispatchd,1)
// (tread,1)
// (implements,1)
// (dust,7)
// (going,3)
// (hole,1)
// (damnable,1)
// (addicted,1)
// (gross,3)
// (givers,1)
// (straws,1)
// (infinite,4)
// (proceeding,1)
// (addition,3)
// (party,1)
// (nony,3)
// (recks,1)
// (blasting,1)
// (truelove,2)
// (curse,1)
// (observance,2)
// (dispatch,2)
// (admiration,3)
// (scale,2)
// (long,17)
// (pardond,2)
// (demanded,1)
// (rivet,1)
// (frenchman,1)
// (accidents,1)
// (grass,1)
// (boistrous,1)
// (certain,4)
// (vanquisher,1)
// (deer,1)
// (trail,2)
// (killd,5)
// (blue,1)
// (continent,2)
// (sick,4)
// (crocodile,1)
// (drunk,1)
// (fadoms,1)
// (attribute,1)
// (gratis,1)
// (rest,14)
// (whet,1)
// (rite,1)
// (bedtime,1)
// (true,22)
// (acting,1)
// (offal,1)
// (corse,3)
// (giantlike,1)
// (owl,1)
// (vigour,1)
// (persons,1)
// (fors,2)
// (knowst,2)
// (translate,2)
// (designd,1)
// (hunts,1)
// (gulf,1)
// (strike,2)
// (perfections,1)
// (curd,1)
// (need,4)
// (blunted,1)
// (oermastert,1)
// (pierce,1)
// (places,1)
// (songs,2)
// (guildenstern,30)
// (low,1)
// (resolutes,1)
// (ossa,1)
// (ourself,3)
// (six,4)
// (three,9)
// (pressures,1)
// (stake,1)
// (frownd,1)
// (blow,3)
// (friend,14)
// (barefoot,1)
// (bestial,1)
// (conscience,8)
// (overdone,2)
// (flattering,1)
// (capitol,1)
// (sun,9)
// (husbands,3)
// (perdition,1)
// (shell,3)
// (asleep,2)
// (taen,2)
// (grunt,1)
// (thats,16)
// (quickly,1)
// (whereto,4)
// (grapples,1)
// (resembles,1)
// (innocent,1)
// (fore,1)
// (blast,2)
// (seagown,1)
// (lean,1)
// (lords,7)
// (placd,2)
// (altitude,1)
// (lodgd,1)
// (cornelius,5)
// (self,1)
// (sipping,1)
// (here,55)
// (flatterd,1)
// (some,53)
// (skirts,1)
// (beds,1)
// (distrust,2)
// (seas,1)
// (dare,6)
// (bedded,1)
// (dozen,2)
// (barkd,1)
// (knockd,1)
// (exercise,2)
// (restraind,1)
// (without,19)
// (welcome,17)
// (undiscoverd,1)
// (fennel,1)
// (affront,1)
// (forts,1)
// (singeing,1)
// (fitness,1)
// (intent,2)
// (too,50)
// (expel,2)
// (ladies,4)
// (tempest,1)
// (mountebank,1)
// (performance,1)
// (beard,6)
// (alack,3)
// (wi,4)
// (thein,1)
// (sextons,1)
// (unsifted,1)
// (nations,1)
// (fiction,1)
// (anon,6)
// (swore,1)
// (horseback,1)
// (enseamed,1)
// (amaking,1)
// (receivd,3)
// (transports,1)
// (shriving,1)
// (cursed,4)
// (monstrous,1)
// (livst,1)
// (society,1)
// (howling,1)
// (divinity,2)
// (into,28)
// (johnadreams,1)
// (scourge,2)
// (colour,5)
// (hatch,1)
// (meditation,1)
// (roscius,1)
// (dram,1)
// (folly,1)
// (appears,2)
// (feard,1)
// (bound,5)
// (replies,1)
// (usd,2)
// (comst,2)
// (maintains,1)
// (cut,2)
// (oblivion,1)
// (instrumental,1)
// (foolish,3)
// (lady,14)
// (pinch,1)
// (possession,1)
// (greatly,1)
// (spirits,5)
// (shirt,1)
// (laid,6)
// (hire,1)
// (vile,5)
// (serious,1)
// (never,26)
// (peasant,2)
// (devoutly,1)
// (precepts,1)
// (motive,5)
// (affections,1)
// (conceive,1)
// (mermaidlike,1)
// (graves,3)
// (embarkd,1)
// (paddock,1)
// (declension,1)
// (quiet,5)
// (vial,1)
// (paragon,1)
// (privates,1)
// (post,2)
// (accidental,1)
// (soeer,1)
// (hang,4)
// (norwegian,1)
// (stranger,1)
// (historicalpastoral,1)
// (audience,5)
// (unpack,1)
// (lawyer,1)
// (rabble,1)
// (hearers,2)
// (feathers,1)
// (noise,10)
// (heroes,1)
// (note,6)
// (invites,1)
// (clawed,1)
// (considered,1)
// (daisies,1)
// (countnance,1)
// (t,7)
// (wings,2)
// (canker,2)
// (maggots,2)
// (portal,1)
// (flash,1)
// (report,5)
// (night,36)
// (reckoning,1)
// (envy,2)
// (chorus,1)
// (offendendo,1)
// (unfold,3)
// (wheaten,1)
// (inch,1)
// (cataplasm,1)
// (flood,1)
// (returnd,4)
// (cold,6)
// (lead,4)
// (slings,1)
// (demands,2)
// (plots,2)
// (pause,4)
// (truepenny,1)
// (dealt,1)
// (flushing,1)
// (dire,1)
// (quarry,1)
// (harmony,1)
// (nobility,1)
// (university,1)
// (worn,1)
// (chamberlain,1)
// (hark,1)
// (winks,1)
// (exterior,1)
// (ecstasy,4)
// (fangd,1)
// (policy,1)
// (line,2)
// (highest,1)
// (chamber,3)
// (lie,10)
// (simple,1)
// (glad,4)
// (tother,1)
// (river,1)
// (bilboes,1)
// (happen,1)
// (unwholesome,1)
// (tyrannically,1)
// (seeming,2)
// (importund,1)
// (lofty,1)
// (dangerous,5)
// (read,5)
// (baseness,1)
// (hue,1)
// (kites,1)
// (late,10)
// (fee,3)
// (met,1)
// (chanson,1)
// (tanner,1)
// (rascal,1)
// (throwing,1)
// (prayers,2)
// (distract,1)
// (respect,2)
// (unless,3)
// (beart,1)
// (perpend,1)
// (nephews,2)
// (chase,1)
// (profession,1)
// (coronation,1)
// (willt,1)
// (marshal,1)
// (offence,9)
// (bosom,4)
// (entreatments,1)
// (eat,5)
// (coronet,1)
// (bulwark,1)
// (draw,9)
// (voice,12)
// (defeats,1)
// (ends,2)
// (tis,73)
// (hoar,1)
// (hilts,1)
// (wheres,2)
// (servd,2)
// (tender,4)
// (overpeering,1)
// (perfume,2)
// (riband,1)
// (hillo,1)
// (rash,3)
// (brave,3)
// (myself,12)
// (kin,2)
// (interim,1)
// (tomb,1)
// (loved,2)
// (wick,1)
// (harsh,3)
// (marrow,1)
// (bloat,1)
// (outward,2)
// (conveniently,1)
// (carters,1)
// (painting,1)
// (frost,1)
// (confusion,1)
// (same,12)
// (tried,1)
// (disclaiming,1)
// (wandring,1)
// (uncurrent,1)
// (drum,3)
// (shall,114)
// (live,16)
// (inurnd,1)
// (fair,20)
// (sighs,1)
// (handsaw,1)
// (passions,1)
// (shrewdly,1)
// (calld,2)
// (fruit,2)
// (fairjudgment,1)
// (vision,1)
// (they,101)
// (cross,1)
// (cup,4)
// (denies,1)
// (lucianus,2)
// (throughly,1)
// (teeth,2)
// (importunity,1)
// (subject,3)
// (deed,11)
// (heart,29)
// (cock,6)
// (wounded,1)
// (clemency,1)
// (dread,5)
// (waterfly,1)
// (seafaring,1)
// (mutinies,1)
// (purer,1)
// (bellowed,1)
// (valentine,1)
// (weeds,4)
// (commune,1)
// (faild,1)
// (lust,2)
// (shook,1)
// (puts,5)
// (players,23)
// (sold,1)
// (tells,1)
// (effects,2)
// (pile,1)
// (suffers,3)
// (larded,2)
// (ministring,1)
// (nomination,1)
// (physic,1)
// (tongue,15)
// (behavd,1)
// (pastoral,1)
// (travel,2)
// (cry,5)
// (jest,3)
// (tediousness,1)
// (maids,3)
// (cannons,1)
// (gravediggers,1)
// (throat,4)
// (steward,1)
// (quite,4)
// (singeth,1)
// (bringing,1)
// (bevy,1)
// (dido,1)
// (shoes,2)
// (mainly,1)
// (screend,1)
// (term,2)
// (beg,7)
// (clowns,3)
// (dew,3)
// (general,7)
// (region,2)
// (dicers,1)
// (peaceparted,1)
// (unseal,1)
// (yoricks,1)
// (unworthiest,1)
// (still,20)
// (chance,2)
// (clappd,1)
// (shouldst,2)
// (hinds,1)
// (dog,2)
// (enginer,1)
// (heir,1)
// (send,4)
// (elder,1)
// (inventorially,1)
// (fretted,1)
// (pomp,1)
// (croaking,1)
// (hearing,4)
// (damnd,5)
// (wisdoms,1)
// (ministers,1)
// (thou,105)
// (satisfaction,1)
// (lacks,1)
// (shent,1)
// (heartily,3)
// (heavenly,2)
// (wassail,1)
// (defy,1)
// (ruin,1)
// (got,2)
// (deal,1)
// (cunning,4)
// (rhapsody,1)
// (diet,2)
// (can,34)
// (writers,1)
// (pestilent,2)
// (split,1)
// (contents,1)
// (woundless,1)
// (churlish,1)
// (neglect,1)
// (accent,2)
// (daintier,1)
// (husbandry,1)
// (walks,2)
// (stirring,1)
// (none,13)
// (howeer,1)
// (satisfied,1)
// (depart,1)
// (hes,10)
// (brazen,1)
// (lightest,1)
// (sit,8)
// (bitter,3)
// (clays,1)
// (turnst,1)
// (fatted,1)
// (restore,1)
// (desperation,2)
// (natures,3)
// (kneels,2)
// (thoughts,17)
// (ominous,1)
// (vicious,1)
// (corrupted,1)
// (inoculate,1)
// (enmity,1)
// (schoolfellows,1)
// (melt,2)
// (poet,1)
// (weeps,1)
// (messengers,2)
// (suits,3)
// (hate,1)
// (intil,1)
// (diction,1)
// (life,33)
// (scanter,1)
// (prodigal,2)
// (ring,2)
// (madam,12)
// (she,47)
// (whipping,1)
// (dear,29)
// (sending,2)
// (illo,1)
// (personal,1)
// (arrows,2)
// (dallying,1)
// (blazon,1)
// (contrive,2)
// (crowner,1)
// (nobler,1)
// (numbers,2)
// (trophy,1)
// (envenom,1)
// (phoebus,1)
// (pronouncing,1)
// (yesterday,1)
// (change,4)
// (clouts,1)
// (prophetic,1)
// (hide,5)
// (overthrown,1)
// (two,26)
// (shelf,1)
// (among,1)
// (removed,1)
// (smote,1)
// (moves,2)
// (speak,63)
// (drooping,1)
// (because,1)
// (stage,5)
// (mellow,1)
// (fast,5)
// (burst,3)
// (threeandtwenty,1)
// (down,29)
// (wonderful,2)
// (positively,1)
// (treble,2)
// (obedience,2)
// (fordo,1)
// (acres,1)
// (tinct,1)
// (scruple,1)
// (war,2)
// (surmise,1)
// (important,1)
// (sicklied,1)
// (fordoes,1)
// (mischief,1)
// (faces,2)
// (propose,2)
// (oath,2)
// (diadem,2)
// (clouds,4)
// (grieve,2)
// (clearly,1)
// (grows,5)
// (sovereign,3)
// (sweet,25)
// (ills,1)
// (country,3)
// (offer,3)
// (pain,1)
// (fortinbras,15)
// (event,2)
// (sort,3)
// (ore,1)
// (meantime,1)
// (proof,6)
// (creatures,3)
// (celestial,2)
// (vouchsafe,3)
// (chaste,3)
// (conquest,1)
// (grand,1)
// (knewst,1)
// (begins,2)
// (edified,1)
// (quietus,1)
// (roof,1)
// (clip,1)
// (over,5)
// (spheres,1)
// (unnatural,4)
// (evil,3)
// (swallowed,1)
// (attend,1)
// (make,55)
// (select,1)
// (knock,1)
// (bonnet,1)
// (me,234)
// (undergo,1)
// (lank,1)
// (accuse,1)
// (books,1)
// (tenures,1)
// (host,1)
// (patiently,1)
// (conqueror,1)
// (scarcely,2)
// (times,7)
// (wax,2)
// (quicksilverr,1)
// (darst,1)
// (sheeted,1)
// (row,1)
// (card,2)
// (bounteous,1)
// (soft,10)
// (our,120)
// (everlasting,1)
// (mart,1)
// (fould,1)
// (tricks,3)
// (solicited,1)
// (garlands,1)
// (inter,1)
// (confederate,1)
// (hatchment,1)
// (patrick,1)
// (practices,1)
// (lands,4)
// (lecture,1)
// (responsive,1)
// (oer,14)
// (pleasures,2)
// (falls,8)
// (scope,3)
// (firm,1)
// (thunder,2)
// (pay,4)
// (pastoralcomical,1)
// (expense,1)
// (rogue,3)
// (slaughters,1)
// (appurtenance,1)
// (contraction,1)
// (heed,2)
// (knavery,2)
// (withdraw,3)
// (congruing,1)
// (sacred,1)
// (luc,1)
// (martial,1)
// (fay,1)
// (ros,45)
// (collection,2)
// (liegemen,1)
// (obeys,1)
// (stoups,1)
// (flaxen,1)
// (sometimes,3)
// (tithe,1)
// (partisan,1)
// (rather,5)
// (foul,11)
// (unkennel,1)
// (sense,13)
// (spend,1)
// (extent,1)
// (commended,1)
// (spoken,2)
// (come,107)
// (bait,1)
// (unworthy,2)
// (whereon,5)
// (especial,1)
// (engagd,1)
// (new,3)
// (preparations,1)
// (pray,28)
// (directly,2)
// (spreads,1)
// (has,12)
// (four,5)
// (vast,1)
// (hadst,3)
// (dukes,1)
// (changeling,1)
// (burthen,1)
// (charity,1)
// (sounds,1)
// (blossoms,1)
// (sailor,2)
// (raind,1)
// (holy,2)
// (chap,1)
// (findst,1)
// (ripe,1)
// (whereat,1)
// (coward,2)
// (dozed,1)
// (withers,1)
// (likes,3)
// (scene,24)
// (poison,6)
// (heaves,1)
// (yard,1)
// (why,64)
// (sparrow,1)
// (fingers,5)
// (couple,1)
// (pretty,2)
// (exhort,1)
// (writ,5)
// (gorge,1)
// (wretched,4)
// (visitation,3)
// (arrant,2)
// (single,2)
// (feel,1)
// (plastring,1)
// (seemd,2)
// (resolution,1)
// (outrageous,1)
// (stock,1)
// (prisoner,2)
// (petty,2)
// (rugged,2)
// (cell,1)
// (wrath,1)
// (rate,2)
// (coinage,1)
// (hair,1)
// (wher,1)
// (muddymettled,1)
// (sweep,2)
// (soldier,3)
// (devil,8)
// (thieves,1)
// (calendar,1)
// (imperfections,1)
// (curb,1)
// (spectators,1)
// (pardont,1)
// (beauties,1)
// (rotten,2)
// (entrance,1)
// (spake,1)
// (poor,20)
// (rebuke,1)
// (fashion,8)
// (unvalued,1)
// (raw,1)
// (laer,62)
// (suffring,1)
// (driven,1)
// (act,19)
// (journeymen,1)
// (sister,7)
// (inheritance,1)
// (bore,4)
// (unhand,1)
// (wharf,1)
// (odds,3)
// (dexterity,1)
// (picked,1)
// (osric,7)
// (works,1)
// (strengthen,1)
// (cheek,2)
// (honesty,5)
// (star,6)
// (strings,1)
// (eyrie,1)
// (ilium,1)
// (politic,1)
// (please,12)
// (gravemaking,1)
// (streets,2)
// (weapon,2)
// (lest,4)
// (wilt,8)
// (lunacy,2)
// (mirth,2)
// (discretion,4)
// (seasoned,1)
// (stoops,1)
// (unction,2)
// (rude,2)
// (behold,1)
// (ins,5)
// (pastors,1)
// (fust,1)
// (jump,2)
// (runs,2)
// (vii,1)
// (mightiest,1)
// (action,10)
// (thee,59)
// (opend,1)
// (seein,1)
// (dejected,1)
// (start,4)
// (exit,40)
// (strumpet,2)
// (angels,3)
// (likelihood,1)
// (pocket,1)
// (letter,3)
// (trust,2)
// (assigns,2)
// (word,12)
// (sounded,1)
// (solemn,3)
// (ship,2)
// (hush,1)
// (sift,1)
// (dirty,1)
// (presently,5)
// (folded,1)
// (drossy,1)
// (unknowing,1)
// (smells,1)
// (courses,1)
// (join,2)
// (griefs,1)
// (staff,1)
// (sunday,1)
// (roasted,1)
// (breathing,2)
// (roar,2)
// (breeding,1)
// (sitting,1)
// (perusal,1)
// (knavish,2)
// (humorous,1)
// (forty,2)
// (idol,1)
// (packet,1)
// (between,15)
// (thicker,1)
// (brokers,1)
// (fear,20)
// (mistook,1)
// (bloodily,1)
// (very,66)
// (shepherds,1)
// (kissd,1)
// (follows,4)
// (juggled,1)
// (wedding,1)
// (flints,1)
// (spilt,1)
// (swear,10)
// (helpful,1)
// (devise,1)
// (haunt,1)
// (royally,1)
// (lads,1)
// (powers,3)
// (ladyship,1)
// (bended,1)
// (weighd,2)
// (thinking,4)
// (nickname,1)
// (index,1)
// (past,3)
// (vengeance,2)
// (poisoning,1)
// (pickaxes,1)
// (wagerd,1)
// (circumscribd,1)
// (canopy,1)
// (rouse,3)
// (congregation,1)
// (desprate,2)
// (forcd,2)
// (gall,2)
// (who,44)
// (ever,13)
// (rapiers,3)
// (cains,1)
// (gertrude,14)
// (kind,12)
// (years,3)
// (tardy,2)
// (brands,1)
// (turk,1)
// (hurts,2)
// (falsely,1)
// (plurisy,1)
// (hither,8)
// (prenominate,1)
// (assume,4)
// (sanctified,1)
// (article,2)
// (weakest,1)
// (trippingly,1)
// (possessd,1)
// (love,66)
// (moving,1)
// (gardners,1)
// (drink,15)
// (horses,2)
// (chaunted,1)
// (whose,32)
// (medicine,1)
// (purpose,12)
// (excellence,3)
// (light,9)
// (greetings,1)
// (poniards,1)
// (merely,2)
// (quoted,1)
// (together,12)
// (metals,1)
// (thrown,2)
// (better,15)
// (worms,2)
// (confine,2)
// (cries,5)
// (ditchers,1)
// (compulsatory,1)
// (rich,3)
// (imports,4)
// (guiltless,1)
// (pious,3)
// (armour,3)
// (charge,8)
// (hinges,1)
// (blush,2)
// (politician,1)
// (salt,3)
// (seest,1)
// (guest,2)
// (kissing,1)
// (thorny,1)
// (talk,2)
// (ordnance,2)
// (again,34)
// (jaw,1)
// (climature,1)
// (gives,9)
// (illume,1)
// (substance,2)
// (rises,3)
// (lifts,1)
// (volume,1)
// (afflicts,1)
// (amities,1)
// (solicitings,1)
// (dulls,1)
// (signet,1)
// (unshaped,1)
// (safety,5)
// (holdst,1)
// (excellent,10)
// (kept,4)
// (after,15)
// (englands,1)
// (rewards,2)
// (occasions,1)
// (according,2)
// (costly,1)
// (beating,3)
// (ways,3)
// (hundred,2)
// (throw,5)
// (whereof,2)
// (air,13)
// (lends,1)
// (daughter,16)
// (speech,16)
// (bleeding,1)
// (objects,1)
// (desire,7)
// (gaudy,1)
// (sin,2)
// (master,1)
// (five,3)
// (peal,1)
// (herald,1)
// (ecstacy,1)
// (headshake,1)
// (discord,1)
// (mass,5)
// (sooner,2)
// (precedent,2)
// (mows,1)
// (english,2)
// (stand,15)
// (fifty,1)
// (deserved,1)
// (crackd,1)
// (francisco,3)
// (craves,1)
// (peruse,1)
// (gent,2)
// (bourn,1)
// (proposer,1)
// (rain,1)
// (flaw,1)
// (monster,1)
// (prey,1)
// (marcellus,12)
// (dish,1)
// (unwatchd,1)
// (basket,2)
// (mind,12)
// (guilty,6)
// (deprivd,1)
// (dost,14)
// (only,6)
// (station,2)
// (ashamd,1)
// (market,1)
// (changed,1)
// (tyrant,1)
// (lifted,1)
// (inmost,1)
// (neptunes,2)
// (regards,1)
// (waxes,2)
// (ophelia,29)
// (clad,1)
// (capt,7)
// (annexment,1)
// (exactly,1)
// (what,208)
// (lobby,2)
// (greenly,1)
// (mouths,1)
// (reckon,1)
// (mixture,1)
// (attendants,9)
// (torrent,1)
// (probation,1)
// (priams,1)
// (mountains,2)
// (rule,1)
// (acquittance,1)
// (load,1)
// (eternity,1)
// (tempt,3)
// (revenue,1)
// (dozy,1)
// (enough,7)
// (hope,8)
// (god,32)
// (mutine,1)
// (nymph,1)
// (greeted,1)
// (ghosts,1)
// (suckd,2)
// (musty,1)
// (linkd,1)
// (tether,1)
// (whirling,1)
// (uncles,1)
// (unwrung,1)
// (paid,1)
// (breed,2)
// (infected,1)
// (seek,9)
// (betoken,1)
// (barrel,1)
// (carpenter,2)
// (own,39)
// (italian,1)
// (woman,7)
// (bray,1)
// (liar,1)
// (bier,1)
// (beat,1)
// (countrymen,1)
// (bank,1)
// (patches,1)
// (normandy,1)
// (comutual,1)
// (sugar,1)
// (counter,1)
// (beshrew,1)
// (ope,1)
// (takes,10)
// (plucks,2)
// (flaming,2)
// (foot,3)
// (purgd,1)
// (disjoint,1)
// (emperor,1)
// (playd,3)
// (lecherous,1)
// (contumely,1)
// (laertes,46)
// (newhatchd,1)
// (empire,2)
// (french,5)
// (fantasy,3)
// (suppliance,1)
// (keeps,4)
// (mad,21)
// (oppressors,1)
// (oerweigh,1)
// (eyes,23)
// (wounds,2)
// (hectic,1)
// (forcing,1)
// (lets,13)
// (fishmonger,2)
// (feed,6)
// (juice,1)
// (lesser,1)
// (destroy,2)
// (upont,2)
// (resolve,1)
// (getrude,1)
// (shoulder,3)
// (noble,17)
// (shame,8)
// (understand,7)
// (their,57)
// (scratchd,1)
// (conception,1)
// (troubles,2)
// (rare,1)
// (demonstrated,1)
// (suchlike,1)
// (generous,3)
// (closet,5)
// (drown,5)
// (salary,1)
// (cellarage,1)
// (talkd,2)
// (guards,1)
// (cliff,1)
// (fitted,1)
// (so,196)
// (length,4)
// (actors,2)
// (mar,32)
// (dreams,3)
// (lisp,1)
// (blest,2)
// (decline,1)
// (young,18)
// (weak,2)

// %% [markdown]
// Use the `take()` operation of an RDD to get the first K records, e.g., K = 10.

// %%
pagecounts.take(10)
// Out:
// Array(20090507-040000 aa Main_Page 7 51309, 20090507-040000 ab %D0%90%D0%B8%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82 1 34069, 20090507-040000 ab %D0%98%D1%85%D0%B0%D0%B4%D0%BE%D1%83_%D0%B0%D0%B4%D0%B0%D2%9F%D1%8C%D0%B0 3 65763, 20090507-040000 af.b Tuisblad 1 36231, 20090507-040000 af.d Tuisblad 1 58960, 20090507-040000 af.q Tuisblad 1 44265, 20090507-040000 af Afrikaans 3 80838, 20090507-040000 af Australi%C3%AB 1 132433, 20090507-040000 af Ensiklopedie 2 60584, 20090507-040000 af Internet 1 48816)

// %% [markdown]
// An alternative way to print the fields is to travers the array and print each record on its own line.

// %%
for (X <- pagecounts.take(10))
{
    println(X)
}
// Out:
// 20090507-040000 aa Main_Page 7 51309
// 20090507-040000 ab %D0%90%D0%B8%D0%BD%D1%82%D0%B5%D1%80%D0%BD%D0%B5%D1%82 1 34069
// 20090507-040000 ab %D0%98%D1%85%D0%B0%D0%B4%D0%BE%D1%83_%D0%B0%D0%B4%D0%B0%D2%9F%D1%8C%D0%B0 3 65763
// 20090507-040000 af.b Tuisblad 1 36231
// 20090507-040000 af.d Tuisblad 1 58960
// 20090507-040000 af.q Tuisblad 1 44265
// 20090507-040000 af Afrikaans 3 80838
// 20090507-040000 af Australi%C3%AB 1 132433
// 20090507-040000 af Ensiklopedie 2 60584
// 20090507-040000 af Internet 1 48816

// %% [markdown]
// Use the `count()` function to see how many records in total are in this data set (this command will take a while, so read ahead while it is running). The pagecounts folder consists of two files, each with around 700K lines, so in total we have around 1400K lines.

// %%
pagecounts.count()
// Out:
// 1398882

// %% [markdown]
// The second field of each record in the data set is the "project code" and contains information about the language of the pages. For example, the project code "en" indicates an English page. Let's derive an RDD, named `enPages`, containing only English pages from pagecounts. This can be done by applying a `filter()` function to `pagecounts`. For each record, we can split it by the field delimiter (i.e., a space) and get the second field, and then compare it with the string "en". To avoid reading from disks each time we perform any operations on the RDD, we can use `cache()` to cache the RDD into memory.

// %%
val enPages = pagecounts.filter(x => x.split(" ")(1) == "en").cache()
enPages.count() //(1) is the second spli
// Out:
// enPages = MapPartitionsRDD[3] at filter at <console>:29
// 970545

// %% [markdown]
// Now, let's generate a histogram of total page views on Wikipedia English pages for the date range represented in our dataset (May 5 to May 7, 2009). The high level idea of what we'll be doing is as follows. First, we generate a key value pair for each line; the key is the date (the first eight characters of the first field), and the value is the number of pageviews for that date (the fourth field).

// %%
val enTuples = enPages.map(x => x.split(" ")) //Methinks that this will be
    //used for the next one - the split is there and which fields are next
val enKeyValuePairs = enTuples.map(x => (x(0).substring(0, 8), x(3).toInt))
//The key-pair values are like so: the key is field one (0) with the first
//eight characters, and the value is the fourth field (3) integer
// Out:
// enTuples = MapPartitionsRDD[4] at map at <console>:27
// enKeyValuePairs = MapPartitionsRDD[5] at map at <console>:29
// MapPartitionsRDD[5] at map at <console>:29

// %% [markdown]
// Next, we shuffle the data and group all values of the same key together. Finally we sum up the values for each key. There is a convenient method called `reduceByKey` in Spark for exactly this pattern. Note that the second argument to `reduceByKey` determines the number of reducers to use. By default, Spark assumes that the reduce function is commutative and associative and applies combiners on the mapper side. Since we know there is a very limited number of keys in this case (because there are only 3 unique dates in our data set), let’s use only one reducer.

// %%
//We basically now reduce the pairs by key and sump up the values for each
//key.
enKeyValuePairs.reduceByKey((x, y) => x + y, 1).collect()
//It says there are 3 unique dates - but the files only contain records
//from two dates only! Also, if you don't write collect(), it won't show
//the summed up values for each key.
// Out:
// Array((20090507,6175726), (20090505,7076855))

// %% [markdown]
// ### Key-Value RDD Operations
// The following steps demonstrate how to develop a simple word count application in Spark. For this part, we will use the file located at `data/story/hamlet.txt`. To convert a text file into an RDD, we use the `SparkContext.textFile()` method. We also apply the recently defined `removePunctuation()` function using a `map()` transformation to strip out the punctuation and change all text to lowercase. Since the file is large we use `take(15)`, so that we only print 15 lines.

// %%
//Here, we define a function that removes punctuations and change all
//texts to lowercase which we will use in the next one
import scala.util.matching
def removePunctuation(text: String): String = {
    text.replaceAll("""\p{Punct}|^\s+|\s+$""", "").toLowerCase
}
// Out:
// removePunctuation: (text: String)String

// %%
//Here we will take the text file Hamlet into an RDDand get rid of
//all the punctuations
val hamletRDD = sc.textFile("data/story/").map(removePunctuation)

//Now we print the first 15 lines -
//btw, https://alvinalexander.com/scala/how-to-use-zipwithindex-create-for-loop-counters-scala-cookbook
hamletRDD.zipWithIndex().take(15).map(x => (x._2 + 1) + ": " + x._1).foreach(println)
// Out:
// 1:
// 2: 1604
// 3:
// 4:
// 5: the tragedy of hamlet prince of denmark
// 6:
// 7:
// 8: by william shakespeare
// 9:
// 10:
// 11:
// 12: dramatis personae
// 13:
// 14: claudius king of denmark
// 15: marcellus officer
// hamletRDD = MapPartitionsRDD[34] at map at <console>:34
// MapPartitionsRDD[34] at map at <console>:34

// %% [markdown]
// To do the word count, first we need to o split each line by its spaces. We can apply the string `split()` transformation to split each element of the RDD by its spaces.

// %%
//For flatmap, https://stackoverflow.com/questions/22350722/what-is-the-difference-between-map-and-flatmap-and-a-good-use-case-for-each
val hamletWordsRDD = hamletRDD.flatMap(_.split(" "))
print(hamletWordsRDD.count())
// Out:
// 33013
// hamletWordsRDD = MapPartitionsRDD[36] at flatMap at <console>:29
// MapPartitionsRDD[36] at flatMap at <console>:29

// %% [markdown]
// The next step is to filter out the empty elements. Remove all entries where the word is `''`.

// %%
val wordsRDD = hamletWordsRDD.filter(_ != "")
print(wordsRDD.count())
// Out:
// 31953
// wordsRDD = MapPartitionsRDD[37] at filter at <console>:28
// MapPartitionsRDD[37] at filter at <console>:28

// %% [markdown]
// We now have an RDD that is only words, so let's produce a list of word counts.

// %%
val wordsCount = wordsRDD.map((_, 1)).reduceByKey(_ + _)
wordsCount.top(5).foreach(println)
//It appears that the top 5 words are sorted alphabetically from the
//bottom. If you want to sort the other way, use takeOdered()
//instead of top()
// Out:
// (zone,1)
// (youth,16)
// (yourselves,1)
// (yourself,15)
// (yours,6)
// wordsCount = ShuffledRDD[74] at reduceByKey at <console>:30
// ShuffledRDD[74] at reduceByKey at <console>:30

// %% [markdown]
// Then, we can take the top 15 words by using the `takeOrdered()` action; however, since the elements of the RDD are pairs, we need a custom sort function that sorts using the value part of the pair.

// %%
val top15WordsAndCounts = wordsCount.map(x => (x._2, x._1)).sortByKey().top(15).map(x => (x._2, x._1))
top15WordsAndCounts.map(x => x._1 + ": " + x._2).foreach(println)
// Out:
// the: 1090
// and: 964
// to: 742
// of: 675
// i: 577
// a: 558
// you: 554
// my: 520
// in: 434
// it: 419
// that: 389
// ham: 358
// is: 346
// not: 315
// his: 304
// top15WordsAndCounts = Array((the,1090), (and,964), (to,742), (of,675), (i,577), (a,558), (you,554), (my,520), (in,434), (it,419), (that,389), (ham,358), (is,346), (not,315), (his,304))
// Array((the,1090), (and,964), (to,742), (of,675), (i,577), (a,558), (you,554), (my,520), (in,434), (it,419), (that,389), (ham,358), (is,346), (not,315), (his,304))

// %% [markdown]
// ## 2. Spark SQL
// The entry point into all functionality in Spark is the `SparkSession` class. To create a basic `SparkSession`, just use `SparkSession.builder()`.

// %%
import org.apache.spark.sql.SparkSession

val spark = SparkSession.builder().appName("Spark SQL ID2221").master("local[*]").getOrCreate()

// For implicit conversions like converting RDDs to DataFrames
import spark.implicits._
// Out:
// spark = org.apache.spark.sql.SparkSession@11c195f0
// org.apache.spark.sql.SparkSession@11c195f0

// %% [markdown]
// ### DataFrame
// Now, let's creates a `DataFrame` based on the content of a JSON file, located at `data/people/people.json`.

// %%
val df = spark.read.json("data/people/people.json")
df.show()
// Out:
// +----+-------+
// | age|   name|
// +----+-------+
// |null|Michael|
// |  30|   Andy|
// |  19| Justin|
// +----+-------+
// df = [age: bigint, name: string]
// [age: bigint, name: string]

// %% [markdown]
// Let's try more functions on `DataFrame`.

// %%
// Print the schema in a tree format
println("Print the schema in a tree format:")
df.printSchema()

// Select only the "name" column
println("Select only the 'name' column:")
df.select("name").show()

// Select everybody, but increment the age by 1
println("Select everybody, but increment the age by 1:")
df.select(df("name"), df("age") + 1).show()

// Select people older than 21
println("Select people older than 21:")
df.filter(df("age") > 21).show()

// Count people by age
println("Count people by age:")
df.groupBy("age").count().show()
// Out:
// Print the schema in a tree format:
// root
//  |-- age: long (nullable = true)
//  |-- name: string (nullable = true)
//
// Select only the 'name' column:
// +-------+
// |   name|
// +-------+
// |Michael|
// |   Andy|
// | Justin|
// +-------+
//
// Select everybody, but increment the age by 1:
// +-------+---------+
// |   name|(age + 1)|
// +-------+---------+
// |Michael|     null|
// |   Andy|       31|
// | Justin|       20|
// +-------+---------+
//
// Select people older than 21:
// +---+----+
// |age|name|
// +---+----+
// | 30|Andy|
// +---+----+
//
// Count people by age:
// +----+-----+
// | age|count|
// +----+-----+
// |  19|    1|
// |null|    1|
// |  30|    1|
// +----+-----+

// %% [markdown]
// The `sql` function on a `SparkSession` enables applications to run SQL queries programmatically and returns the result as a `DataFrame`.

// %%
// Register the DataFrame as a SQL temporary view
df.createOrReplaceTempView("people")

val sqlDF = spark.sql("SELECT * FROM people")
sqlDF.show()
// Out:
// +----+-------+
// | age|   name|
// +----+-------+
// |null|Michael|
// |  30|   Andy|
// |  19| Justin|
// +----+-------+
// sqlDF = [age: bigint, name: string]
// [age: bigint, name: string]

// %% [markdown]
// Temporary views in Spark SQL are session-scoped and will disappear if the session that creates it terminates. If you want to have a temporary view that is shared among all sessions and keep alive until the Spark application terminates, you can create a global temporary view. Global temporary view is tied to a system preserved database `global_temp`, and we must use the qualified name to refer it, e.g. `SELECT * FROM global_temp.people`.

// %%
// Register the DataFrame as a global temporary view
df.createGlobalTempView("people")

// Global temporary view is tied to a system preserved database `global_temp`
spark.sql("SELECT * FROM global_temp.people").show()

// Global temporary view is cross-session
spark.newSession().sql("SELECT * FROM global_temp.people").show()
// Out:
// +----+-------+
// | age|   name|
// +----+-------+
// |null|Michael|
// |  30|   Andy|
// |  19| Justin|
// +----+-------+
//
// +----+-------+
// | age|   name|
// +----+-------+
// |null|Michael|
// |  30|   Andy|
// |  19| Justin|
// +----+-------+

// %% [markdown]
// ### Dataset
// Datasets are similar to RDDs, however, instead of using Java serialization or Kryo they use a specialized Encoder to serialize the objects for processing or transmitting over the network. While both encoders and standard serialization are responsible for turning an object into bytes, encoders are code generated dynamically and use a format that allows Spark to perform many operations like filtering, sorting and hashing without deserializing the bytes back into an object.

// %%
//Check https://www.youtube.com/watch?v=mtlZhyxWR9Q

case class Person(name: String, age: Long)

// Encoders are created for case classes
val caseClassDS = Seq(Person("Andy", 32)).toDS()
caseClassDS.show()z

// DataFrames can be converted to a Dataset by providing a class. Mapping will be done by name
val peopleDS = spark.read.json("data/people/people.json").as[Person]
peopleDS.show()

// Encoders for most common types are automatically provided by importing spark.implicits._
val primitiveDS = Seq(1, 2, 3).toDS()
primitiveDS.map(_ + 1).collect()
// Out:
// Name: Unknown Error
// Message: <console>:20: error: value toDS is not a member of Seq[Person]
//        val caseClassDS = Seq(Person("Andy", 32)).toDS()
//                                                  ^
// <console>:24: error: Unable to find encoder for type Person. An implicit Encoder[Person] is needed to store Person instances in a Dataset. Primitive types (Int, String, etc) and Product types (case classes) are supported by importing spark.implicits._  Support for serializing other types will be added in future releases.
//        val peopleDS = spark.read.json("data/people/people.json").as[Person]
//                                                                    ^
// <console>:28: error: value toDS is not a member of Seq[Int]
//        val primitiveDS = Seq(1, 2, 3).toDS()
//                                       ^
//
// StackTrace:

// %% [markdown]
// ### Interoperating with RDDs
// Spark SQL supports two different methods for converting existing RDDs into Datasets:
// 1. The first method uses reflection to infer the schema of an RDD that contains specific types of objects. This reflection based approach leads to more concise code and works well when you already know the schema while writing your Spark application.
// 2. The second method for creating Datasets is through a programmatic interface that allows you to construct a schema and then apply it to an existing RDD. While this method is more verbose, it allows you to construct Datasets when the columns and their types are not known until runtime.
//
// Let's start with the first method. The Scala interface for Spark SQL supports automatically converting an RDD containing case classes to a DataFrame. The case class defines the schema of the table. The names of the arguments to the case class are read using reflection and become the names of the columns. Case classes can also be nested or contain complex types such as `Seqs` or `Arrays`. This RDD can be implicitly converted to a DataFrame and then be registered as a table. Tables can be used in subsequent SQL statements.

// %% [raw]
// // For implicit conversions from RDDs to DataFrames
// import spark.implicits._
//
// // Create an instance of SparkContext
// val sc = spark.sparkContext
//
// // Create an RDD of Person objects from a text file, convert it to a Dataframe
// val peopleRDD = sc.textFile("data/people/people.txt")
// val peopleDF = peopleRDD.map(_.split(",")).map(x => Person(x(0), x(1).trim.toInt)).toDF()
//
// // Register the DataFrame as a temporary view
// //peopleDF.createOrReplaceTempView("people")
//
// // SQL statements can be run by using the sql methods provided by Spark
// val teenagersDF = spark.sql("SELECT name, age FROM people WHERE age BETWEEN 13 AND 19")
//
// // The columns of a row in the result can be accessed by field index
// teenagersDF.map(teenager => "Name: " + teenager(0)).show()
//
// // or by field name
// teenagersDF.map(teenager => "Name: " + teenager.getAs[String]("name")).show()

// %% [markdown]
// In the second method we can specify the schema programmatically. When case classes cannot be defined ahead of time (for example, the structure of records is encoded in a string, or a text dataset will be parsed and fields will be projected differently for different users), a DataFrame can be created programmatically with three steps.
// 1. Create an RDD of Rows from the original RDD.
// 2. Create the schema represented by a `StructType` matching the structure of Rows in the RDD created in Step 1.
// 3. Apply the schema to the RDD of `Row`s via `createDataFrame` method provided by `SparkSession`.

// %%
import org.apache.spark.sql.types._
import org.apache.spark.sql.Row
import org.apache.spark.sql.types.{StructType,StructField,StringType}

// Create an RDD
val peopleRDD = spark.sparkContext.textFile("data/people/people.txt")

// The schema is encoded in a string
val schemaString = "name age"

// Generate the schema based on the string of schema
val fields = schemaString.split(" ").map(x => StructField(x, StringType, nullable = true))
val schema = StructType(fields)

// Convert records of the RDD (people) to Rows
val rowRDD = peopleRDD.map(_.split(",")).map(x => Row(x(0), x(1).trim))

// Apply the schema to the RDD
val peopleDF = spark.createDataFrame(rowRDD, schema)

// Creates a temporary view using the DataFrame
peopleDF.createOrReplaceTempView("people")

// SQL can be run over a temporary view created using DataFrames
val results = spark.sql("SELECT name FROM people")

// The results of SQL queries are DataFrames and support all the normal RDD operations
// The columns of a row in the result can be accessed by field index or by field name
results.map(attributes => "Name: " + attributes(0)).show()
// Out:
// +-------------+
// |        value|
// +-------------+
// |Name: Michael|
// |   Name: Andy|
// | Name: Justin|
// +-------------+
// peopleRDD = data/people/people.txt MapPartitionsRDD[359] at textFile at <console>:37
// schemaString = name age
// fields = Array(StructField(name,StringType,true), StructField(age,StringType,true))
// schema = StructType(StructField(name,StringType,true), StructField(age,StringType,true))
// rowRDD = MapPartitionsRDD[361] at map at <console>:47
// peopleDF = [name: string, age: string]
// results = [name: string]
// [name: string]

// %% [markdown]
// ### Data Sources
// Spark SQL supports operating on a variety of data sources through the `DataFrame` interface. A `DataFrame` can be operated on as normal RDDs and can also be registered as a temporary table. Registering a DataFrame as a table allows you to run SQL queries over its data. In the simplest form, the default data source (*parquet* unless otherwise configured by `spark.sql.sources.default`) will be used for all operations. Save operations also can optionally take a `SaveMode` that specifies how to handle existing data if present. It can take the values: `error` (default), `append`, `overwrite`, `ignore`.

// %%
// Load data from a parquet file
val pdf = spark.read.load("data/people/people.parquet")
pdf.select("name", "favorite_color").write.mode("overwrite").save("namesAndFavColors.parquet")
// Out:
// pdf = [name: string, favorite_color: string ... 1 more field]
// [name: string, favorite_color: string ... 1 more field]

// %%
// Manually specify the data source type, e.g., json, parquet, jdbc.
val jdf =  spark.read.format("json").load("data/people/people.json")
jdf.select("name", "age").write.format("parquet").mode("overwrite").save("namesAndAges.parquet")
// Out:
// jdf = [age: bigint, name: string]
// [age: bigint, name: string]

// %% [markdown]
// *Parquet* is a columnar format that is supported by many other data processing systems. Spark SQL provides support for both reading and writing Parquet files that automatically preserves the schema of the original data. Let's load data programmatically.

// %%
// Encoders for most common types are automatically provided by importing spark.implicits._
import spark.implicits._

val peopleDF = spark.read.json("data/people/people.json")

// DataFrames can be saved as Parquet files, maintaining the schema information
peopleDF.write.parquet("people.parquet")

// Read in the parquet file created above
val parquetFileDF = spark.read.parquet("people.parquet")

// Parquet files can also be used to create a temporary view and then used in SQL statements
parquetFileDF.createOrReplaceTempView("parquetFile")
val namesDF = spark.sql("SELECT name FROM parquetFile WHERE age BETWEEN 13 AND 19")
namesDF.map(attributes => "Name: " + attributes(0)).show()
// Out:
// +------------+
// |       value|
// +------------+
// |Name: Justin|
// +------------+
// peopleDF = [age: bigint, name: string]
// parquetFileDF = [age: bigint, name: string]
// namesDF = [name: string]
// [name: string]

// %% [markdown]
// Spark SQL can automatically infer the schema of a JSON dataset and load it as a `Dataset[Row]`. This conversion can be done using `SparkSession.read.json()` on either a `Dataset[String]`, or a JSON file. Note that the file that is offered as a json file is not a typical JSON file. Each line must contain a separate, self-contained valid JSON object. For a regular multi-line JSON file, set the `multiLine` option to `true`.

// %%
// supported by importing this when creating a Dataset.
import spark.implicits._

// Read a JSON dataset
val peopleDF = spark.read.json("data/people/people.json")

// The inferred schema can be visualized using the printSchema() method
peopleDF.printSchema()

// Creates a temporary view using the DataFrame
peopleDF.createOrReplaceTempView("people")

// SQL statements can be run by using the sql methods provided by spark
val teenagerNamesDF = spark.sql("SELECT name FROM people WHERE age BETWEEN 13 AND 19")
teenagerNamesDF.show()

// Alternatively, a DataFrame can be created for a JSON dataset represented by a Dataset[String] storing 
// one JSON object per string
val otherPeopleDataset = spark.createDataset("""{"name":"Yin","address":{"city":"Columbus","state":"Ohio"}}""" :: Nil)
val otherPeople = spark.read.json(otherPeopleDataset)
otherPeople.show()
// Out:
// root
//  |-- age: long (nullable = true)
//  |-- name: string (nullable = true)
//
// +------+
// |  name|
// +------+
// |Justin|
// +------+
//
// +----------------+----+
// |         address|name|
// +----------------+----+
// |[Columbus, Ohio]| Yin|
// +----------------+----+
// peopleDF = [age: bigint, name: string]
// teenagerNamesDF = [name: string]
// otherPeopleDataset = [value: string]
// otherPeople = [address: struct<city: string, state: string>, name: string]
// [address: struct<city: string, state: string>, name: string]
